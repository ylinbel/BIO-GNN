# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys
import helper


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
import scipy.io
import numpy as np

connectivity_matrices_asd = []

for i in range(1, 155):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/ASD_LH/LHASDSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_asd.append(connectivity_matrix)

connectivity_matrices_asd = np.stack(connectivity_matrices_asd)

connectivity_matrices_control = []

for i in range(1, 186):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/NC_LH/LHNCSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_control.append(connectivity_matrix)

connectivity_matrices_control = np.stack(connectivity_matrices_control)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# #### 3. train DGN for ASD

# %%
Dataset = "E" 
N_Subjects = 155
N_Nodes = 35
N_views = 6
N_max_epochs = 500
early_stop =  True
random_sample_size = 10
n_folds = 5
lr = 0.001
model_name = "ASD_LH_original_322"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = CONV2 = CONV3 = 8

lambda_r = 0
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_asd
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
# lambda2 = 50
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 0.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 25.60 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 25.60 | median cbt mc 10.23 | Time Elapsed: 7.42 |
# Epoch: 10  |  cbt loss : 18.02 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 18.02 | median cbt mc 10.23 | Time Elapsed: 32.96 |
# Epoch: 20  |  cbt loss : 15.13 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 15.13 | median cbt mc 10.24 | Time Elapsed: 32.25 |
# Epoch: 30  |  cbt loss : 13.44 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 13.44 | median cbt mc 10.26 | Time Elapsed: 31.65 |
# Epoch: 40  |  cbt loss : 12.62 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 12.62 | median cbt mc 10.26 | Time Elapsed: 32.27 |
# Epoch: 50  |  cbt loss : 12.10 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 12.10 | median cbt mc 10.27 | Time Elapsed: 33.14 |
# Epoch: 60  |  cbt loss : 11.73 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.73 | median cbt mc 10.26 | Time Elapsed: 32.12 |
# Epoch: 70  |  cbt loss : 11.46 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.46 | median cbt mc 10.24 | Time Elapsed: 32.19 |
# Epoch: 80  |  cbt loss : 11.27 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.27 | median cbt mc 10.26 | Time Elapsed: 31.60 |
# Epoch: 90  |  cbt loss : 11.17 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.17 | median cbt mc 10.27 | Time Elapsed: 31.68 |
# Epoch: 100  |  cbt loss : 11.11 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.11 | median cbt mc 10.26 | Time Elapsed: 31.45 |
# Epoch: 110  |  cbt loss : 11.08 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.08 | median cbt mc 10.26 | Time Elapsed: 31.72 |
# Epoch: 120  |  cbt loss : 11.06 | reservoir loss : 0.0937 | bio loss : 0.00000 | total loss: 11.06 | median cbt mc 10.26 | Time Elapsed: 31.83 |
# Epoch: 200  |  cbt loss : 11.01 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.01 | median cbt mc 10.26 | Time Elapsed: 95.08 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.01 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.01 | median cbt mc 10.25 | Time Elapsed: 94.93 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 11.01 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.01 | median cbt mc 10.26 | Time Elapsed: 94.98 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.6066219156672967
# FINAL RESULTS  REP: 11.01127815246582, RESERVOIR LOSS: 0.08302845060825348, MEMORY FINGERPRINT: 10.405872524384526

# %%
Dataset = "E" 
N_Subjects = 186
N_Nodes = 35
N_views = 6
N_max_epochs = 500
early_stop =  True
random_sample_size = 10
n_folds = 5
lr = 0.001
model_name = "CONTROL_original_322"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = CONV2 = CONV3 = 8

lambda_r = 0
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_control
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
# lambda2 = 50
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 0.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 140  |  cbt loss : 11.16 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.27 | Time Elapsed: 141.54 |
# Epoch: 150  |  cbt loss : 11.10 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.10 | median cbt mc 10.26 | Time Elapsed: 140.15 |
# Epoch: 160  |  cbt loss : 11.05 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.26 | Time Elapsed: 139.95 |
# Epoch: 170  |  cbt loss : 11.02 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.02 | median cbt mc 10.26 | Time Elapsed: 139.74 |
# Epoch: 180  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.25 | Time Elapsed: 140.47 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.27 | Time Elapsed: 118.83 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.26 | Time Elapsed: 117.17 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.25 | Time Elapsed: 117.82 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.25 | Time Elapsed: 117.99 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.27 | Time Elapsed: 116.78 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 11.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.00 | median cbt mc 10.27 | Time Elapsed: 118.61 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.6347343987879432
# FINAL RESULTS  REP: 10.996721267700195, RESERVOIR LOSS: 0.08302842080593109, MEMORY FINGERPRINT: 10.419607601256866
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 91.78 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 91.78 | median cbt mc 9.25 | Time Elapsed: 21.25 |
# Epoch: 10  |  cbt loss : 65.11 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 65.11 | median cbt mc 9.28 | Time Elapsed: 145.77 |
# Epoch: 20  |  cbt loss : 45.28 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 45.28 | median cbt mc 9.27 | Time Elapsed: 44.17 |
# Epoch: 30  |  cbt loss : 32.70 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 32.70 | median cbt mc 10.15 | Time Elapsed: 32.09 |
# Epoch: 40  |  cbt loss : 24.84 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 24.84 | median cbt mc 10.22 | Time Elapsed: 32.30 |
# Epoch: 50  |  cbt loss : 16.96 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 16.96 | median cbt mc 10.27 | Time Elapsed: 32.47 |
# Epoch: 60  |  cbt loss : 13.40 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 13.40 | median cbt mc 10.26 | Time Elapsed: 32.51 |
# Epoch: 70  |  cbt loss : 12.50 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.26 | Time Elapsed: 32.82 |
# Epoch: 80  |  cbt loss : 12.00 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 12.00 | median cbt mc 10.27 | Time Elapsed: 32.35 |
# Epoch: 90  |  cbt loss : 11.69 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.69 | median cbt mc 10.26 | Time Elapsed: 32.92 |
# Epoch: 100  |  cbt loss : 11.49 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.49 | median cbt mc 10.26 | Time Elapsed: 32.55 |
# Epoch: 110  |  cbt loss : 11.34 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.34 | median cbt mc 10.25 | Time Elapsed: 32.88 |
# Epoch: 120  |  cbt loss : 11.24 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.24 | median cbt mc 10.25 | Time Elapsed: 48.82 |
# Epoch: 130  |  cbt loss : 11.20 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.20 | median cbt mc 10.26 | Time Elapsed: 139.48 |
# Epoch: 140  |  cbt loss : 11.19 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.19 | median cbt mc 10.26 | Time Elapsed: 142.10 |
# Epoch: 150  |  cbt loss : 11.18 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 141.93 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.18 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 127.78 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.18 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 118.00 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.18 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.23 | Time Elapsed: 62.63 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.18 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 61.62 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5610049413469052
# FINAL RESULTS  REP: 11.18288516998291, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.418261012403821
