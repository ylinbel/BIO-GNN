# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
connectivity_matrices_ad = []

for i in range(1, 42):
    mat = scipy.io.loadmat(f'data_ad_lmci_R/data_ad_lmci_R/AD_RH/subject{i}.mat')
    connectivity_matrix = mat['A'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_ad.append(connectivity_matrix)

connectivity_matrices_ad = np.stack(connectivity_matrices_ad)

connectivity_matrices_lmci = []

for i in range(42, 78):
    mat = scipy.io.loadmat(f'data_ad_lmci_R/data_ad_lmci_R/LMCI_RH/subject{i}.mat')
    connectivity_matrix = mat['A'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_lmci.append(connectivity_matrix)

connectivity_matrices_lmci = np.stack(connectivity_matrices_lmci)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %%
Dataset = "E" 

#Number of simulated subjects (overwriten if Dataset = "E") 
N_Subjects = 41

#Number of nodes for simulated brain networks (overwriten if Dataset = "E") 
N_Nodes = 35

#Number of brain views (overwriten if Dataset = "E")
N_views = 4

#Number of training epochs
N_max_epochs = 500

#Apply early stopping True/False
early_stop =  True

#Random subset size for SNL function  
random_sample_size = 10

#Number of cross validation folds
n_folds = 5

#Learning Rate for Adam optimizer
lr = 0.002

#Name of the model
model_name = "AD_RH_RC_loss_only"

CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_ad
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 54.77 | reservoir loss : 0.0896 | bio loss : 0.00000 | total loss: 58.35 | median cbt mc 9.26 | Time Elapsed: 6.37 |
# Epoch: 10  |  cbt loss : 27.85 | reservoir loss : 0.0885 | bio loss : 0.00000 | total loss: 27.85 | median cbt mc 9.27 | Time Elapsed: 10.45 |
# Epoch: 20  |  cbt loss : 17.93 | reservoir loss : 0.0883 | bio loss : 0.00000 | total loss: 17.93 | median cbt mc 9.27 | Time Elapsed: 9.23 |
# Epoch: 30  |  cbt loss : 14.26 | reservoir loss : 0.0882 | bio loss : 0.00000 | total loss: 14.26 | median cbt mc 10.25 | Time Elapsed: 10.20 |
# Epoch: 40  |  cbt loss : 12.82 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.82 | median cbt mc 10.30 | Time Elapsed: 11.42 |
# CBT loss has converged.
# Epoch: 50  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.25 | Time Elapsed: 17.03 |
# CBT loss has converged.
# Epoch: 60  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.26 | Time Elapsed: 15.75 |
# CBT loss has converged.
# Epoch: 70  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.26 | Time Elapsed: 8.48 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.27 | Time Elapsed: 8.13 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.25 | Time Elapsed: 8.13 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.27 | Time Elapsed: 8.07 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.27 | Time Elapsed: 8.10 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.26 | Time Elapsed: 7.98 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.25 | Time Elapsed: 8.13 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.26 | Time Elapsed: 8.13 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.85 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.85 | median cbt mc 10.26 | Time Elapsed: 8.25 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4150175912169707
# FINAL RESULTS  REP: 12.849964141845703, RESERVOIR LOSS: 0.0830284059047699, MEMORY FINGERPRINT: 10.432599874633128
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 95.10 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 95.10 | median cbt mc 9.27 | Time Elapsed: 2.97 |
# Epoch: 10  |  cbt loss : 47.55 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 47.55 | median cbt mc 9.27 | Time Elapsed: 9.34 |
# Epoch: 20  |  cbt loss : 24.65 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 24.65 | median cbt mc 9.29 | Time Elapsed: 9.30 |
# Epoch: 30  |  cbt loss : 17.67 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 17.67 | median cbt mc 10.24 | Time Elapsed: 9.64 |
# Epoch: 40  |  cbt loss : 14.10 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 14.10 | median cbt mc 10.26 | Time Elapsed: 9.53 |
# Epoch: 50  |  cbt loss : 13.29 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.29 | median cbt mc 10.26 | Time Elapsed: 9.25 |
# Epoch: 60  |  cbt loss : 12.87 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.87 | median cbt mc 10.26 | Time Elapsed: 9.37 |
# Epoch: 70  |  cbt loss : 12.78 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.78 | median cbt mc 10.27 | Time Elapsed: 9.68 |
# Epoch: 80  |  cbt loss : 12.71 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.71 | median cbt mc 10.25 | Time Elapsed: 9.48 |
# Epoch: 90  |  cbt loss : 12.60 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.60 | median cbt mc 10.25 | Time Elapsed: 9.58 |
# Epoch: 100  |  cbt loss : 12.56 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.56 | median cbt mc 10.25 | Time Elapsed: 9.24 |
# Epoch: 110  |  cbt loss : 12.55 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.55 | median cbt mc 10.25 | Time Elapsed: 9.17 |
# Epoch: 120  |  cbt loss : 12.53 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.53 | median cbt mc 10.25 | Time Elapsed: 9.26 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.52 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.52 | median cbt mc 10.26 | Time Elapsed: 9.47 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.52 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.52 | median cbt mc 10.26 | Time Elapsed: 8.36 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.52 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.52 | median cbt mc 10.25 | Time Elapsed: 8.17 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.52 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.52 | median cbt mc 10.27 | Time Elapsed: 8.36 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.3540093992625708
# FINAL RESULTS  REP: 12.52341365814209, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.430938891297586
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 40.55 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 40.55 | median cbt mc 9.26 | Time Elapsed: 3.00 |
# Epoch: 10  |  cbt loss : 21.57 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 21.57 | median cbt mc 9.27 | Time Elapsed: 9.63 |
# Epoch: 20  |  cbt loss : 14.74 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 14.74 | median cbt mc 10.26 | Time Elapsed: 9.47 |
# Epoch: 30  |  cbt loss : 12.53 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.53 | median cbt mc 10.25 | Time Elapsed: 9.35 |
# Epoch: 40  |  cbt loss : 12.20 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.26 | Time Elapsed: 9.49 |
# Epoch: 50  |  cbt loss : 12.12 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.12 | median cbt mc 10.27 | Time Elapsed: 9.63 |
# Epoch: 60  |  cbt loss : 12.23 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.23 | median cbt mc 10.27 | Time Elapsed: 9.75 |
# Epoch: 70  |  cbt loss : 12.35 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.26 | Time Elapsed: 9.32 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 12.41 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 8.84 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.41 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 8.23 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.41 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 8.44 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.41 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 8.67 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4236843305266986
# FINAL RESULTS  REP: 12.410160064697266, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.44531721714677
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 43.16 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 43.16 | median cbt mc 9.27 | Time Elapsed: 3.01 |
# Epoch: 10  |  cbt loss : 20.91 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 20.91 | median cbt mc 9.74 | Time Elapsed: 9.25 |
# Epoch: 20  |  cbt loss : 13.85 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.85 | median cbt mc 10.26 | Time Elapsed: 9.52 |
# Epoch: 30  |  cbt loss : 12.56 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.56 | median cbt mc 10.26 | Time Elapsed: 9.46 |
# Epoch: 40  |  cbt loss : 12.15 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.15 | median cbt mc 10.26 | Time Elapsed: 9.50 |
# Epoch: 50  |  cbt loss : 12.00 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.00 | median cbt mc 10.26 | Time Elapsed: 9.25 |
# Epoch: 60  |  cbt loss : 12.04 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.04 | median cbt mc 10.27 | Time Elapsed: 9.33 |
# Epoch: 70  |  cbt loss : 12.08 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.08 | median cbt mc 10.27 | Time Elapsed: 13.84 |
# Epoch: 80  |  cbt loss : 12.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.26 | Time Elapsed: 28.45 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.25 | Time Elapsed: 10.31 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.26 | Time Elapsed: 7.78 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.26 | Time Elapsed: 8.15 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.20 | median cbt mc 10.29 | Time Elapsed: 8.34 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4074171202199905
# FINAL RESULTS  REP: 12.204587936401367, RESERVOIR LOSS: 0.08302842825651169, MEMORY FINGERPRINT: 10.452525467519992
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 143.44 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 143.44 | median cbt mc 9.26 | Time Elapsed: 2.96 |
# Epoch: 10  |  cbt loss : 83.03 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 83.03 | median cbt mc 9.27 | Time Elapsed: 9.92 |
# Epoch: 20  |  cbt loss : 44.86 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 44.86 | median cbt mc 9.32 | Time Elapsed: 9.72 |
# Epoch: 30  |  cbt loss : 24.95 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 24.95 | median cbt mc 10.24 | Time Elapsed: 9.23 |
# Epoch: 40  |  cbt loss : 16.90 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 16.90 | median cbt mc 10.26 | Time Elapsed: 9.60 |
# Epoch: 50  |  cbt loss : 13.72 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.72 | median cbt mc 10.26 | Time Elapsed: 9.35 |
# Epoch: 60  |  cbt loss : 12.97 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.97 | median cbt mc 10.27 | Time Elapsed: 9.36 |
# Epoch: 70  |  cbt loss : 12.62 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.62 | median cbt mc 10.28 | Time Elapsed: 9.27 |
# Epoch: 80  |  cbt loss : 12.56 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.56 | median cbt mc 10.25 | Time Elapsed: 9.65 |
# Epoch: 90  |  cbt loss : 12.48 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.24 | Time Elapsed: 9.52 |
# Epoch: 100  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 9.38 |
# Epoch: 110  |  cbt loss : 12.41 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 9.51 |
# Epoch: 120  |  cbt loss : 12.42 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.42 | median cbt mc 10.26 | Time Elapsed: 9.42 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.25 | Time Elapsed: 8.67 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.25 | Time Elapsed: 8.36 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 8.50 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 8.58 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 8.60 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 11.66 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.41988440713316005
# FINAL RESULTS  REP: 12.425314903259277, RESERVOIR LOSS: 0.08302845060825348, MEMORY FINGERPRINT: 10.408242389994006

# %%
Dataset = "E" 

#Number of simulated subjects (overwriten if Dataset = "E") 
N_Subjects = 36

#Number of nodes for simulated brain networks (overwriten if Dataset = "E") 
N_Nodes = 35

#Number of brain views (overwriten if Dataset = "E")
N_views = 4

#Number of training epochs
N_max_epochs = 500

#Apply early stopping True/False
early_stop =  True

#Random subset size for SNL function  
random_sample_size = 10

#Number of cross validation folds
n_folds = 5

#Learning Rate for Adam optimizer
lr = 0.001

#Name of the model
model_name = "LMCI_RH_RC_loss_only"

CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_lmci
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 57.24 | reservoir loss : 0.0897 | bio loss : 0.00000 | total loss: 60.83 | median cbt mc 9.26 | Time Elapsed: 2.71 |
# Epoch: 10  |  cbt loss : 38.37 | reservoir loss : 0.0892 | bio loss : 0.00000 | total loss: 38.37 | median cbt mc 9.26 | Time Elapsed: 8.42 |
# Epoch: 20  |  cbt loss : 28.19 | reservoir loss : 0.0890 | bio loss : 0.00000 | total loss: 28.19 | median cbt mc 9.27 | Time Elapsed: 8.12 |
# Epoch: 30  |  cbt loss : 21.30 | reservoir loss : 0.0890 | bio loss : 0.00000 | total loss: 21.30 | median cbt mc 9.28 | Time Elapsed: 8.29 |
# Epoch: 40  |  cbt loss : 17.59 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 17.59 | median cbt mc 9.31 | Time Elapsed: 9.29 |
# Epoch: 50  |  cbt loss : 15.18 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 15.18 | median cbt mc 10.26 | Time Elapsed: 13.52 |
# Epoch: 60  |  cbt loss : 13.91 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 13.91 | median cbt mc 10.26 | Time Elapsed: 14.19 |
# Epoch: 70  |  cbt loss : 12.96 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.96 | median cbt mc 10.27 | Time Elapsed: 8.79 |
# Epoch: 80  |  cbt loss : 12.62 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.62 | median cbt mc 10.33 | Time Elapsed: 8.32 |
# Epoch: 90  |  cbt loss : 12.58 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.58 | median cbt mc 10.26 | Time Elapsed: 8.50 |
# Epoch: 100  |  cbt loss : 12.47 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.26 | Time Elapsed: 8.20 |
# Epoch: 110  |  cbt loss : 12.40 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.40 | median cbt mc 10.26 | Time Elapsed: 8.37 |
# Epoch: 120  |  cbt loss : 12.36 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.36 | median cbt mc 10.26 | Time Elapsed: 8.45 |
# Epoch: 130  |  cbt loss : 12.34 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.34 | median cbt mc 10.25 | Time Elapsed: 8.24 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.33 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.33 | median cbt mc 10.27 | Time Elapsed: 7.52 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.33 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.33 | median cbt mc 10.26 | Time Elapsed: 7.50 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.33 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.33 | median cbt mc 10.26 | Time Elapsed: 7.63 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 12.33 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.33 | median cbt mc 10.26 | Time Elapsed: 7.35 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4330303757615658
# FINAL RESULTS  REP: 12.3333158493042, RESERVOIR LOSS: 0.08302845805883408, MEMORY FINGERPRINT: 10.423227423067758
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 97.51 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 97.51 | median cbt mc 9.26 | Time Elapsed: 7.75 |
# Epoch: 10  |  cbt loss : 69.90 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 69.90 | median cbt mc 9.26 | Time Elapsed: 8.23 |
# Epoch: 20  |  cbt loss : 49.07 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 49.07 | median cbt mc 9.27 | Time Elapsed: 8.39 |
# Epoch: 30  |  cbt loss : 34.15 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 34.15 | median cbt mc 9.27 | Time Elapsed: 8.33 |
# Epoch: 40  |  cbt loss : 25.41 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 25.41 | median cbt mc 9.34 | Time Elapsed: 8.41 |
# Epoch: 50  |  cbt loss : 20.65 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 20.65 | median cbt mc 10.18 | Time Elapsed: 8.58 |
# Epoch: 60  |  cbt loss : 17.36 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 17.36 | median cbt mc 10.25 | Time Elapsed: 8.50 |
# Epoch: 70  |  cbt loss : 15.39 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 15.39 | median cbt mc 10.26 | Time Elapsed: 8.64 |
# Epoch: 80  |  cbt loss : 14.37 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 14.37 | median cbt mc 10.27 | Time Elapsed: 8.67 |
# Epoch: 90  |  cbt loss : 13.88 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.88 | median cbt mc 10.25 | Time Elapsed: 8.52 |
# Epoch: 100  |  cbt loss : 13.58 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.58 | median cbt mc 10.27 | Time Elapsed: 8.86 |
# Epoch: 110  |  cbt loss : 13.41 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.41 | median cbt mc 10.25 | Time Elapsed: 8.70 |
# Epoch: 120  |  cbt loss : 13.27 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.27 | median cbt mc 10.27 | Time Elapsed: 8.48 |
# Epoch: 130  |  cbt loss : 13.13 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.13 | median cbt mc 10.26 | Time Elapsed: 8.53 |
# Epoch: 140  |  cbt loss : 13.03 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.03 | median cbt mc 10.27 | Time Elapsed: 8.79 |
# Epoch: 150  |  cbt loss : 12.95 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.95 | median cbt mc 10.25 | Time Elapsed: 8.43 |
# Epoch: 160  |  cbt loss : 12.89 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.89 | median cbt mc 10.25 | Time Elapsed: 8.53 |
# Epoch: 170  |  cbt loss : 12.83 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.83 | median cbt mc 10.25 | Time Elapsed: 8.91 |
# Epoch: 180  |  cbt loss : 12.76 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.76 | median cbt mc 10.26 | Time Elapsed: 8.65 |
# Epoch: 190  |  cbt loss : 12.68 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.68 | median cbt mc 10.26 | Time Elapsed: 8.83 |
# Epoch: 200  |  cbt loss : 12.69 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.69 | median cbt mc 10.26 | Time Elapsed: 9.44 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 12.70 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.70 | median cbt mc 10.27 | Time Elapsed: 8.76 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 12.70 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.70 | median cbt mc 10.26 | Time Elapsed: 8.03 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 12.70 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.70 | median cbt mc 10.27 | Time Elapsed: 8.38 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 12.70 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.70 | median cbt mc 10.25 | Time Elapsed: 15.93 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.43637939567012074
# FINAL RESULTS  REP: 12.696969985961914, RESERVOIR LOSS: 0.0830283984541893, MEMORY FINGERPRINT: 10.423296373205066
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 42.33 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 42.33 | median cbt mc 9.26 | Time Elapsed: 2.68 |
# Epoch: 10  |  cbt loss : 28.84 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 28.84 | median cbt mc 9.26 | Time Elapsed: 8.19 |
# Epoch: 20  |  cbt loss : 22.26 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 22.26 | median cbt mc 9.27 | Time Elapsed: 8.32 |
# Epoch: 30  |  cbt loss : 18.10 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 18.10 | median cbt mc 10.07 | Time Elapsed: 8.28 |
# Epoch: 40  |  cbt loss : 15.25 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 15.25 | median cbt mc 10.24 | Time Elapsed: 8.36 |
# Epoch: 50  |  cbt loss : 13.38 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 13.38 | median cbt mc 10.25 | Time Elapsed: 8.71 |
# Epoch: 60  |  cbt loss : 12.78 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.78 | median cbt mc 9.29 | Time Elapsed: 8.65 |
# Epoch: 70  |  cbt loss : 12.49 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.49 | median cbt mc 10.26 | Time Elapsed: 8.57 |
# Epoch: 80  |  cbt loss : 12.34 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.34 | median cbt mc 10.25 | Time Elapsed: 8.76 |
# Epoch: 90  |  cbt loss : 12.28 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.25 | Time Elapsed: 8.46 |
# Epoch: 100  |  cbt loss : 12.25 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.25 | median cbt mc 10.27 | Time Elapsed: 8.50 |
# Epoch: 110  |  cbt loss : 12.27 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.27 | median cbt mc 10.25 | Time Elapsed: 8.38 |
# Epoch: 120  |  cbt loss : 12.31 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.31 | median cbt mc 10.27 | Time Elapsed: 8.36 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.35 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.26 | Time Elapsed: 8.75 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.35 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.26 | Time Elapsed: 27.82 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.35 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.25 | Time Elapsed: 25.44 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.35 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.26 | Time Elapsed: 27.80 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.43157412125899347
# FINAL RESULTS  REP: 12.353614807128906, RESERVOIR LOSS: 0.08302836865186691, MEMORY FINGERPRINT: 10.441811478274644
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 43.81 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 43.81 | median cbt mc 9.27 | Time Elapsed: 10.13 |
# Epoch: 10  |  cbt loss : 29.80 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 29.80 | median cbt mc 9.51 | Time Elapsed: 26.57 |
# Epoch: 20  |  cbt loss : 21.19 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 21.19 | median cbt mc 10.25 | Time Elapsed: 8.10 |
# Epoch: 30  |  cbt loss : 15.92 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 15.92 | median cbt mc 10.27 | Time Elapsed: 7.82 |
# Epoch: 40  |  cbt loss : 13.87 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.87 | median cbt mc 10.27 | Time Elapsed: 7.89 |
# Epoch: 50  |  cbt loss : 13.20 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.20 | median cbt mc 10.27 | Time Elapsed: 8.22 |
# Epoch: 60  |  cbt loss : 12.87 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.87 | median cbt mc 10.26 | Time Elapsed: 8.28 |
# Epoch: 70  |  cbt loss : 12.60 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.60 | median cbt mc 10.26 | Time Elapsed: 8.21 |
# Epoch: 80  |  cbt loss : 12.51 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.51 | median cbt mc 10.26 | Time Elapsed: 8.27 |
# Epoch: 90  |  cbt loss : 12.44 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.44 | median cbt mc 10.26 | Time Elapsed: 8.04 |
# Epoch: 100  |  cbt loss : 12.42 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.42 | median cbt mc 10.27 | Time Elapsed: 7.78 |
# Epoch: 110  |  cbt loss : 12.42 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.42 | median cbt mc 10.26 | Time Elapsed: 8.19 |
# Epoch: 120  |  cbt loss : 12.44 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.44 | median cbt mc 10.27 | Time Elapsed: 8.26 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.46 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.29 | Time Elapsed: 7.93 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.46 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.26 | Time Elapsed: 7.31 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.46 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.26 | Time Elapsed: 7.42 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.46 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.26 | Time Elapsed: 7.26 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.375156717084685
# FINAL RESULTS  REP: 12.456196784973145, RESERVOIR LOSS: 0.08302835375070572, MEMORY FINGERPRINT: 10.38539733548174
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 146.55 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 146.55 | median cbt mc 9.26 | Time Elapsed: 2.73 |
# Epoch: 10  |  cbt loss : 113.07 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 113.07 | median cbt mc 9.28 | Time Elapsed: 8.27 |
# Epoch: 20  |  cbt loss : 85.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 85.30 | median cbt mc 9.27 | Time Elapsed: 8.33 |
# Epoch: 30  |  cbt loss : 63.16 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 63.16 | median cbt mc 9.28 | Time Elapsed: 8.37 |
# Epoch: 40  |  cbt loss : 46.38 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 46.38 | median cbt mc 9.37 | Time Elapsed: 8.46 |
# Epoch: 50  |  cbt loss : 33.32 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 33.32 | median cbt mc 10.14 | Time Elapsed: 8.36 |
# Epoch: 60  |  cbt loss : 25.31 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 25.31 | median cbt mc 10.24 | Time Elapsed: 21.33 |
# Epoch: 70  |  cbt loss : 20.07 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 20.07 | median cbt mc 10.24 | Time Elapsed: 32.37 |
# Epoch: 80  |  cbt loss : 16.78 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 16.78 | median cbt mc 10.24 | Time Elapsed: 33.12 |
# Epoch: 90  |  cbt loss : 14.77 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 14.77 | median cbt mc 10.26 | Time Elapsed: 32.97 |
# Epoch: 100  |  cbt loss : 13.59 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.59 | median cbt mc 10.27 | Time Elapsed: 19.56 |
# Epoch: 110  |  cbt loss : 13.09 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.09 | median cbt mc 10.26 | Time Elapsed: 8.38 |
# Epoch: 120  |  cbt loss : 12.83 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.83 | median cbt mc 10.26 | Time Elapsed: 8.50 |
# Epoch: 130  |  cbt loss : 12.67 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.67 | median cbt mc 10.27 | Time Elapsed: 8.31 |
# Epoch: 140  |  cbt loss : 12.57 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.57 | median cbt mc 10.26 | Time Elapsed: 8.53 |
# Epoch: 150  |  cbt loss : 12.48 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.25 | Time Elapsed: 8.61 |
# Epoch: 160  |  cbt loss : 12.41 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.41 | median cbt mc 10.26 | Time Elapsed: 8.25 |
# Epoch: 170  |  cbt loss : 12.37 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.37 | median cbt mc 10.26 | Time Elapsed: 8.50 |
# Epoch: 180  |  cbt loss : 12.34 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.34 | median cbt mc 10.26 | Time Elapsed: 8.21 |
# Epoch: 190  |  cbt loss : 12.31 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.31 | median cbt mc 10.26 | Time Elapsed: 8.80 |
# Epoch: 200  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.26 | Time Elapsed: 8.48 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.26 | Time Elapsed: 7.84 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.26 | Time Elapsed: 8.04 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.26 | Time Elapsed: 8.12 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.25 | Time Elapsed: 7.79 |
# CBT loss has converged.
# Epoch: 250  |  cbt loss : 12.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.28 | median cbt mc 10.27 | Time Elapsed: 8.16 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4225031295410247
# FINAL RESULTS  REP: 12.278717994689941, RESERVOIR LOSS: 0.08302844315767288, MEMORY FINGERPRINT: 10.4217673721811

# %% [markdown]
# ### analysis

# %%
import numpy as np

memory_capacity_asd = [
10.432599874633128,
10.430938891297586,
10.44531721714677,
10.452525467519992,
10.408242389994006,
]

bio = [
0.4150175912169707,
0.3540093992625708,
0.4236843305266986,
0.4074171202199905,
0.41988440713316005,
]

fb = [
12.849964141845703,
12.52341365814209,
12.410160064697266,
12.204587936401367,
12.425314903259277,
]

print("asd",  "memory capacity", np.mean(memory_capacity_asd), np.std(memory_capacity_asd), "bio", np.mean(bio), np.std(bio), "fb", np.mean(fb), np.std(fb))
# Out:
# asd memory capacity 10.433924768118297 0.015139545979672561 bio 0.40400256967187814 0.025580896833971366 fb 12.48268814086914 0.21092271693799783

# %%
memory_capacity_nc = [
10.423227423067758,
10.423296373205066,
10.441811478274644,
10.38539733548174,
10.4217673721811,
]

bio = [
0.4330303757615658,
0.43637939567012074,
0.43157412125899347,
0.375156717084685,
0.4225031295410247,
]

fb = [
12.3333158493042,
12.696969985961914,
12.353614807128906,
12.456196784973145,
12.278717994689941,
]

print("lmci",  "memory capacity", np.mean(memory_capacity_nc), np.std(memory_capacity_nc), "bio", np.mean(bio), np.std(bio), "fb", np.mean(fb), np.std(fb))
# Out:
# lmci memory capacity 10.41909999644206 0.018403482739193386 bio 0.41972874786327796 0.022754574790303624 fb 12.423763084411622 0.14821168454849035
