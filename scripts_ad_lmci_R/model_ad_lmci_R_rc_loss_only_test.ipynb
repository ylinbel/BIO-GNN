# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
connectivity_matrices_ad = []

for i in range(1, 42):
    mat = scipy.io.loadmat(f'data_ad_lmci_R/data_ad_lmci_R/AD_RH/subject{i}.mat')
    connectivity_matrix = mat['A'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_ad.append(connectivity_matrix)

connectivity_matrices_ad = np.stack(connectivity_matrices_ad)

connectivity_matrices_lmci = []

for i in range(42, 78):
    mat = scipy.io.loadmat(f'data_ad_lmci_R/data_ad_lmci_R/LMCI_RH/subject{i}.mat')
    connectivity_matrix = mat['A'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_lmci.append(connectivity_matrix)

connectivity_matrices_lmci = np.stack(connectivity_matrices_lmci)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %%
Dataset = "E" 

#Number of simulated subjects (overwriten if Dataset = "E") 
N_Subjects = 41

#Number of nodes for simulated brain networks (overwriten if Dataset = "E") 
N_Nodes = 35

#Number of brain views (overwriten if Dataset = "E")
N_views = 4

#Number of training epochs
N_max_epochs = 500

#Apply early stopping True/False
early_stop =  True

#Random subset size for SNL function  
random_sample_size = 10

#Number of cross validation folds
n_folds = 5

#Learning Rate for Adam optimizer
lr = 0.002

#Name of the model
model_name = "AD_RH_RC_loss_only_test"

CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_ad
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 57.33 | reservoir loss : 0.0896 | bio loss : 0.00000 | total loss: 60.91 | median cbt mc 9.26 | Time Elapsed: 4.27 |
# Epoch: 10  |  cbt loss : 28.52 | reservoir loss : 0.0885 | bio loss : 0.00000 | total loss: 28.52 | median cbt mc 9.28 | Time Elapsed: 3.05 |
# Epoch: 20  |  cbt loss : 17.95 | reservoir loss : 0.0883 | bio loss : 0.00000 | total loss: 17.95 | median cbt mc 10.22 | Time Elapsed: 3.11 |
# Epoch: 30  |  cbt loss : 14.23 | reservoir loss : 0.0882 | bio loss : 0.00000 | total loss: 14.23 | median cbt mc 10.26 | Time Elapsed: 3.28 |
# Epoch: 40  |  cbt loss : 12.61 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.61 | median cbt mc 10.27 | Time Elapsed: 3.52 |
# CBT loss has converged.
# Epoch: 50  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.25 | Time Elapsed: 4.27 |
# CBT loss has converged.
# Epoch: 60  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.35 | Time Elapsed: 4.30 |
# CBT loss has converged.
# Epoch: 70  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.26 | Time Elapsed: 3.02 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.28 | Time Elapsed: 2.84 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.26 | Time Elapsed: 2.55 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.19 | Time Elapsed: 2.94 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.38 | Time Elapsed: 2.97 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.66 | Time Elapsed: 2.89 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 10.30 | Time Elapsed: 2.74 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.23 | Time Elapsed: 2.78 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.24 | Time Elapsed: 2.84 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.63 | reservoir loss : 0.0881 | bio loss : 0.00000 | total loss: 12.63 | median cbt mc 11.23 | Time Elapsed: 2.83 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 1.155693430166137
# FINAL RESULTS  REP: 12.626108169555664, RESERVOIR LOSS: 0.08302848041057587, MEMORY FINGERPRINT: 11.384226048759157
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 87.95 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 87.95 | median cbt mc 9.27 | Time Elapsed: 2.05 |
# Epoch: 10  |  cbt loss : 43.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 43.66 | median cbt mc 9.29 | Time Elapsed: 3.00 |
# Epoch: 20  |  cbt loss : 23.62 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 23.62 | median cbt mc 10.26 | Time Elapsed: 2.62 |
# Epoch: 30  |  cbt loss : 17.20 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 17.20 | median cbt mc 10.25 | Time Elapsed: 2.97 |
# Epoch: 40  |  cbt loss : 13.98 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.98 | median cbt mc 10.26 | Time Elapsed: 6.26 |
# Epoch: 50  |  cbt loss : 13.17 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.17 | median cbt mc 10.25 | Time Elapsed: 3.96 |
# Epoch: 60  |  cbt loss : 12.80 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.80 | median cbt mc 10.26 | Time Elapsed: 2.80 |
# Epoch: 70  |  cbt loss : 12.75 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.75 | median cbt mc 10.25 | Time Elapsed: 2.90 |
# Epoch: 80  |  cbt loss : 12.69 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.69 | median cbt mc 10.26 | Time Elapsed: 2.94 |
# Epoch: 90  |  cbt loss : 12.60 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.60 | median cbt mc 10.26 | Time Elapsed: 2.97 |
# Epoch: 100  |  cbt loss : 12.56 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.56 | median cbt mc 10.25 | Time Elapsed: 2.84 |
# Epoch: 110  |  cbt loss : 12.49 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.49 | median cbt mc 10.27 | Time Elapsed: 2.84 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.47 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.27 | Time Elapsed: 2.98 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.47 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.25 | Time Elapsed: 2.59 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.47 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.26 | Time Elapsed: 2.46 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.47 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.27 | Time Elapsed: 2.60 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.3884074182827717
# FINAL RESULTS  REP: 12.468502044677734, RESERVOIR LOSS: 0.0830283984541893, MEMORY FINGERPRINT: 10.422373852641263
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 40.85 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 40.85 | median cbt mc 9.26 | Time Elapsed: 2.04 |
# Epoch: 10  |  cbt loss : 21.61 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 21.61 | median cbt mc 9.29 | Time Elapsed: 3.04 |
# Epoch: 20  |  cbt loss : 14.77 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 14.77 | median cbt mc 10.27 | Time Elapsed: 3.02 |
# Epoch: 30  |  cbt loss : 12.68 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.68 | median cbt mc 9.39 | Time Elapsed: 2.86 |
# Epoch: 40  |  cbt loss : 12.31 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.31 | median cbt mc 10.26 | Time Elapsed: 2.86 |
# Epoch: 50  |  cbt loss : 12.19 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.19 | median cbt mc 10.25 | Time Elapsed: 2.88 |
# Epoch: 60  |  cbt loss : 12.29 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.29 | median cbt mc 10.27 | Time Elapsed: 2.78 |
# Epoch: 70  |  cbt loss : 12.40 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.40 | median cbt mc 10.26 | Time Elapsed: 2.84 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.26 | Time Elapsed: 2.82 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.26 | Time Elapsed: 2.69 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.26 | Time Elapsed: 2.84 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.27 | Time Elapsed: 2.54 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.27 | Time Elapsed: 2.60 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.26 | Time Elapsed: 2.56 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.50 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.50 | median cbt mc 10.29 | Time Elapsed: 2.55 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.3856768742253136
# FINAL RESULTS  REP: 12.498112678527832, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.47359830298609
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 43.14 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 43.14 | median cbt mc 9.28 | Time Elapsed: 1.94 |
# Epoch: 10  |  cbt loss : 20.84 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 20.84 | median cbt mc 10.25 | Time Elapsed: 2.97 |
# Epoch: 20  |  cbt loss : 13.91 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.91 | median cbt mc 10.28 | Time Elapsed: 2.62 |
# Epoch: 30  |  cbt loss : 12.79 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.79 | median cbt mc 10.26 | Time Elapsed: 2.85 |
# Epoch: 40  |  cbt loss : 12.37 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.37 | median cbt mc 10.26 | Time Elapsed: 2.70 |
# Epoch: 50  |  cbt loss : 12.21 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.21 | median cbt mc 10.24 | Time Elapsed: 2.80 |
# Epoch: 60  |  cbt loss : 12.43 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.25 | Time Elapsed: 2.95 |
# CBT loss has converged.
# Epoch: 70  |  cbt loss : 12.48 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.26 | Time Elapsed: 2.94 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 12.48 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.25 | Time Elapsed: 2.55 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 12.48 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.26 | Time Elapsed: 2.82 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 12.48 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.25 | Time Elapsed: 2.58 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 12.48 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.27 | Time Elapsed: 2.64 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4104305272656504
# FINAL RESULTS  REP: 12.482050895690918, RESERVOIR LOSS: 0.08302844315767288, MEMORY FINGERPRINT: 10.448379220064178
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 144.82 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 144.82 | median cbt mc 9.27 | Time Elapsed: 2.23 |
# Epoch: 10  |  cbt loss : 84.31 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 84.31 | median cbt mc 9.28 | Time Elapsed: 2.98 |
# Epoch: 20  |  cbt loss : 45.84 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 45.84 | median cbt mc 9.33 | Time Elapsed: 2.75 |
# Epoch: 30  |  cbt loss : 25.42 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 25.42 | median cbt mc 10.25 | Time Elapsed: 2.62 |
# Epoch: 40  |  cbt loss : 17.00 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 17.00 | median cbt mc 10.26 | Time Elapsed: 2.95 |
# Epoch: 50  |  cbt loss : 13.74 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.74 | median cbt mc 10.26 | Time Elapsed: 2.83 |
# Epoch: 60  |  cbt loss : 12.93 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.93 | median cbt mc 10.26 | Time Elapsed: 2.87 |
# Epoch: 70  |  cbt loss : 12.53 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.53 | median cbt mc 10.26 | Time Elapsed: 2.58 |
# Epoch: 80  |  cbt loss : 12.45 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.45 | median cbt mc 10.25 | Time Elapsed: 2.72 |
# Epoch: 90  |  cbt loss : 12.36 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.36 | median cbt mc 10.26 | Time Elapsed: 2.73 |
# Epoch: 100  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.26 | Time Elapsed: 2.96 |
# Epoch: 110  |  cbt loss : 12.29 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.29 | median cbt mc 10.27 | Time Elapsed: 2.89 |
# Epoch: 120  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.27 | Time Elapsed: 2.75 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.26 | Time Elapsed: 2.69 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.26 | Time Elapsed: 2.68 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.27 | Time Elapsed: 2.57 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.30 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.30 | median cbt mc 10.26 | Time Elapsed: 2.50 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.4074179070320496
# FINAL RESULTS  REP: 12.30320930480957, RESERVOIR LOSS: 0.08302837610244751, MEMORY FINGERPRINT: 10.419563042848676

# %%
Dataset = "E" 

#Number of simulated subjects (overwriten if Dataset = "E") 
N_Subjects = 36

#Number of nodes for simulated brain networks (overwriten if Dataset = "E") 
N_Nodes = 35

#Number of brain views (overwriten if Dataset = "E")
N_views = 4

#Number of training epochs
N_max_epochs = 500

#Apply early stopping True/False
early_stop =  True

#Random subset size for SNL function  
random_sample_size = 10

#Number of cross validation folds
n_folds = 5

#Learning Rate for Adam optimizer
lr = 0.001

#Name of the model
model_name = "LMCI_RH_RC_loss_only_test"

CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_lmci
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 55.83 | reservoir loss : 0.0897 | bio loss : 0.00000 | total loss: 59.42 | median cbt mc 9.26 | Time Elapsed: 2.39 |
# Epoch: 10  |  cbt loss : 37.31 | reservoir loss : 0.0892 | bio loss : 0.00000 | total loss: 37.31 | median cbt mc 9.26 | Time Elapsed: 2.86 |
# Epoch: 20  |  cbt loss : 27.71 | reservoir loss : 0.0890 | bio loss : 0.00000 | total loss: 27.71 | median cbt mc 9.28 | Time Elapsed: 2.98 |
# Epoch: 30  |  cbt loss : 21.13 | reservoir loss : 0.0890 | bio loss : 0.00000 | total loss: 21.13 | median cbt mc 9.34 | Time Elapsed: 2.95 |
# Epoch: 40  |  cbt loss : 17.57 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 17.57 | median cbt mc 10.22 | Time Elapsed: 2.95 |
# Epoch: 50  |  cbt loss : 15.25 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 15.25 | median cbt mc 10.25 | Time Elapsed: 3.99 |
# Epoch: 60  |  cbt loss : 13.95 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 13.95 | median cbt mc 10.25 | Time Elapsed: 4.34 |
# Epoch: 70  |  cbt loss : 13.04 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 13.04 | median cbt mc 10.26 | Time Elapsed: 3.02 |
# Epoch: 80  |  cbt loss : 12.72 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.72 | median cbt mc 10.82 | Time Elapsed: 3.10 |
# Epoch: 90  |  cbt loss : 12.71 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.71 | median cbt mc 10.26 | Time Elapsed: 2.99 |
# Epoch: 100  |  cbt loss : 12.57 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.57 | median cbt mc 10.26 | Time Elapsed: 2.88 |
# Epoch: 110  |  cbt loss : 12.48 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.48 | median cbt mc 10.27 | Time Elapsed: 2.87 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.46 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.41 | Time Elapsed: 2.80 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.46 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.25 | Time Elapsed: 2.70 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.46 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.27 | Time Elapsed: 2.71 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.46 | reservoir loss : 0.0889 | bio loss : 0.00000 | total loss: 12.46 | median cbt mc 10.27 | Time Elapsed: 2.52 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.3817419869265592
# FINAL RESULTS  REP: 12.464365005493164, RESERVOIR LOSS: 0.08302827179431915, MEMORY FINGERPRINT: 10.42350851090405
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 97.48 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 97.48 | median cbt mc 9.27 | Time Elapsed: 2.26 |
# Epoch: 10  |  cbt loss : 69.99 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 69.99 | median cbt mc 10.14 | Time Elapsed: 2.43 |
# Epoch: 20  |  cbt loss : 49.18 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 49.18 | median cbt mc 9.58 | Time Elapsed: 2.76 |
# Epoch: 30  |  cbt loss : 34.07 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 34.07 | median cbt mc 10.25 | Time Elapsed: 2.34 |
# Epoch: 40  |  cbt loss : 25.12 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 25.12 | median cbt mc 10.26 | Time Elapsed: 2.63 |
# Epoch: 50  |  cbt loss : 20.42 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 20.42 | median cbt mc 10.26 | Time Elapsed: 5.19 |
# Epoch: 60  |  cbt loss : 17.12 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 17.12 | median cbt mc 10.26 | Time Elapsed: 8.36 |
# Epoch: 70  |  cbt loss : 15.17 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 15.17 | median cbt mc 10.27 | Time Elapsed: 8.28 |
# Epoch: 80  |  cbt loss : 14.10 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 14.10 | median cbt mc 10.33 | Time Elapsed: 8.18 |
# Epoch: 90  |  cbt loss : 13.62 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.62 | median cbt mc 11.26 | Time Elapsed: 7.84 |
# Epoch: 100  |  cbt loss : 13.30 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.30 | median cbt mc 11.25 | Time Elapsed: 7.89 |
# Epoch: 110  |  cbt loss : 13.11 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 13.11 | median cbt mc 11.24 | Time Elapsed: 8.35 |
# Epoch: 120  |  cbt loss : 12.97 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.97 | median cbt mc 11.25 | Time Elapsed: 7.71 |
# Epoch: 130  |  cbt loss : 12.84 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.84 | median cbt mc 10.69 | Time Elapsed: 2.49 |
# Epoch: 140  |  cbt loss : 12.74 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.74 | median cbt mc 10.26 | Time Elapsed: 2.43 |
# Epoch: 150  |  cbt loss : 12.68 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.68 | median cbt mc 11.24 | Time Elapsed: 2.61 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 10.90 | Time Elapsed: 2.13 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 11.25 | Time Elapsed: 2.24 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 11.07 | Time Elapsed: 2.56 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 11.24 | Time Elapsed: 1.93 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 11.24 | Time Elapsed: 2.57 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 12.66 | reservoir loss : 0.0943 | bio loss : 0.00000 | total loss: 12.66 | median cbt mc 11.19 | Time Elapsed: 2.33 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 1.1603592412226447
# FINAL RESULTS  REP: 12.66207218170166, RESERVOIR LOSS: 0.0830284059047699, MEMORY FINGERPRINT: 11.4020700505306
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 43.89 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 43.89 | median cbt mc 9.26 | Time Elapsed: 2.19 |
# Epoch: 10  |  cbt loss : 29.52 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 29.52 | median cbt mc 9.28 | Time Elapsed: 2.64 |
# Epoch: 20  |  cbt loss : 22.51 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 22.51 | median cbt mc 9.25 | Time Elapsed: 2.24 |
# Epoch: 30  |  cbt loss : 18.17 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 18.17 | median cbt mc 9.32 | Time Elapsed: 2.38 |
# Epoch: 40  |  cbt loss : 15.20 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 15.20 | median cbt mc 10.26 | Time Elapsed: 2.63 |
# Epoch: 50  |  cbt loss : 13.28 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 13.28 | median cbt mc 10.26 | Time Elapsed: 2.63 |
# Epoch: 60  |  cbt loss : 12.72 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.72 | median cbt mc 10.26 | Time Elapsed: 2.77 |
# Epoch: 70  |  cbt loss : 12.42 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.42 | median cbt mc 10.26 | Time Elapsed: 2.52 |
# Epoch: 80  |  cbt loss : 12.23 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.23 | median cbt mc 10.26 | Time Elapsed: 2.77 |
# Epoch: 90  |  cbt loss : 12.17 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.17 | median cbt mc 10.28 | Time Elapsed: 2.57 |
# Epoch: 100  |  cbt loss : 12.16 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.16 | median cbt mc 10.28 | Time Elapsed: 2.67 |
# Epoch: 110  |  cbt loss : 12.18 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.18 | median cbt mc 10.27 | Time Elapsed: 2.50 |
# Epoch: 120  |  cbt loss : 12.22 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.22 | median cbt mc 10.31 | Time Elapsed: 2.61 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.26 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.26 | median cbt mc 10.32 | Time Elapsed: 2.78 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.26 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.26 | median cbt mc 10.27 | Time Elapsed: 2.24 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.26 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.26 | median cbt mc 10.27 | Time Elapsed: 2.38 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.26 | reservoir loss : 0.0926 | bio loss : 0.00000 | total loss: 12.26 | median cbt mc 10.27 | Time Elapsed: 2.13 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.3827090553144284
# FINAL RESULTS  REP: 12.25913143157959, RESERVOIR LOSS: 0.0830283910036087, MEMORY FINGERPRINT: 10.471635380363189
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 43.21 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 43.21 | median cbt mc 10.25 | Time Elapsed: 2.26 |
# Epoch: 10  |  cbt loss : 29.36 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 29.36 | median cbt mc 10.23 | Time Elapsed: 2.62 |
# Epoch: 20  |  cbt loss : 20.81 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 20.81 | median cbt mc 10.25 | Time Elapsed: 2.67 |
# Epoch: 30  |  cbt loss : 15.68 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 15.68 | median cbt mc 10.28 | Time Elapsed: 2.65 |
# Epoch: 40  |  cbt loss : 13.73 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.73 | median cbt mc 10.28 | Time Elapsed: 2.59 |
# Epoch: 50  |  cbt loss : 13.09 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 13.09 | median cbt mc 10.28 | Time Elapsed: 2.62 |
# Epoch: 60  |  cbt loss : 12.76 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.76 | median cbt mc 10.26 | Time Elapsed: 2.66 |
# Epoch: 70  |  cbt loss : 12.52 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.52 | median cbt mc 10.26 | Time Elapsed: 2.68 |
# Epoch: 80  |  cbt loss : 12.43 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 2.57 |
# Epoch: 90  |  cbt loss : 12.37 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.37 | median cbt mc 11.26 | Time Elapsed: 2.53 |
# Epoch: 100  |  cbt loss : 12.34 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.34 | median cbt mc 11.25 | Time Elapsed: 2.57 |
# Epoch: 110  |  cbt loss : 12.34 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.34 | median cbt mc 11.19 | Time Elapsed: 2.69 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 11.23 | Time Elapsed: 2.59 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 11.09 | Time Elapsed: 2.44 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 11.21 | Time Elapsed: 2.38 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 11.23 | Time Elapsed: 2.57 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 10.26 | Time Elapsed: 2.29 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 12.35 | reservoir loss : 0.0908 | bio loss : 0.00000 | total loss: 12.35 | median cbt mc 11.16 | Time Elapsed: 2.52 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 1.105609119376023
# FINAL RESULTS  REP: 12.348478317260742, RESERVOIR LOSS: 0.08302848041057587, MEMORY FINGERPRINT: 10.679142089785017
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 138.13 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 138.13 | median cbt mc 9.32 | Time Elapsed: 1.93 |
# Epoch: 10  |  cbt loss : 106.28 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 106.28 | median cbt mc 9.27 | Time Elapsed: 2.73 |
# Epoch: 20  |  cbt loss : 80.18 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 80.18 | median cbt mc 9.34 | Time Elapsed: 2.47 |
# Epoch: 30  |  cbt loss : 59.23 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 59.23 | median cbt mc 9.45 | Time Elapsed: 2.69 |
# Epoch: 40  |  cbt loss : 43.23 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 43.23 | median cbt mc 9.85 | Time Elapsed: 2.41 |
# Epoch: 50  |  cbt loss : 31.32 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 31.32 | median cbt mc 9.29 | Time Elapsed: 2.62 |
# Epoch: 60  |  cbt loss : 24.12 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 24.12 | median cbt mc 10.25 | Time Elapsed: 2.62 |
# Epoch: 70  |  cbt loss : 19.53 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 19.53 | median cbt mc 10.26 | Time Elapsed: 2.67 |
# Epoch: 80  |  cbt loss : 16.55 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 16.55 | median cbt mc 10.26 | Time Elapsed: 2.64 |
# Epoch: 90  |  cbt loss : 14.60 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 14.60 | median cbt mc 11.25 | Time Elapsed: 2.64 |
# Epoch: 100  |  cbt loss : 13.57 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.57 | median cbt mc 11.24 | Time Elapsed: 2.58 |
# Epoch: 110  |  cbt loss : 13.15 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 13.15 | median cbt mc 11.23 | Time Elapsed: 2.80 |
# Epoch: 120  |  cbt loss : 12.94 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.94 | median cbt mc 11.25 | Time Elapsed: 2.65 |
# Epoch: 130  |  cbt loss : 12.78 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.78 | median cbt mc 10.43 | Time Elapsed: 2.80 |
# Epoch: 140  |  cbt loss : 12.65 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.65 | median cbt mc 10.28 | Time Elapsed: 2.53 |
# Epoch: 150  |  cbt loss : 12.56 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.56 | median cbt mc 11.13 | Time Elapsed: 2.73 |
# Epoch: 160  |  cbt loss : 12.51 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.51 | median cbt mc 10.26 | Time Elapsed: 2.79 |
# Epoch: 170  |  cbt loss : 12.47 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.47 | median cbt mc 10.27 | Time Elapsed: 2.77 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.25 | Time Elapsed: 2.65 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.27 | Time Elapsed: 2.51 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 2.43 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 2.68 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.31 | Time Elapsed: 2.33 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.27 | Time Elapsed: 2.19 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 12.43 | reservoir loss : 0.0917 | bio loss : 0.00000 | total loss: 12.43 | median cbt mc 10.26 | Time Elapsed: 2.17 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.40940810957290136
# FINAL RESULTS  REP: 12.43260669708252, RESERVOIR LOSS: 0.08302835375070572, MEMORY FINGERPRINT: 10.410113930582899

# %% [markdown]
# ### analysis
