# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
import scipy.io
import numpy as np

connectivity_matrices_control = []

for i in range(1, 186):
    mat = scipy.io.loadmat(f'data_nc_asd_R/data_nc_asd_R/NC_RH/RHNCSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_control.append(connectivity_matrix)

connectivity_matrices_control = np.stack(connectivity_matrices_control)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# #### 3. train DGN for ASD

# %%
Dataset = "E" 

#Number of simulated subjects (overwriten if Dataset = "E") 
N_Subjects = 185

#Number of nodes for simulated brain networks (overwriten if Dataset = "E") 
N_Nodes = 35

#Number of brain views (overwriten if Dataset = "E")
N_views = 6

#Number of training epochs
N_max_epochs = 500

#Apply early stopping True/False
early_stop =  True

#Random subset size for SNL function  
random_sample_size = 10

#Number of cross validation folds
n_folds = 5

#Learning Rate for Adam optimizer
lr = 0.001

#Name of the model
model_name = "THREE_LOSSES_229_NC_ALL"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = 8
#dimension of embeddings output by the second GDL layer (for each ROI)
CONV2 = 8
#dimension of embeddings output by the third GDL layer (for each ROI)
CONV3 = 8

lambda1 = 200
lambda2 = 50
patience = 3

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_control
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda1" : lambda1,
        "lambda2" : lambda2,
        "patience" : patience,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 27.93 | reservoir loss : 0.0937 | bio loss : 0.59664 | total loss: 76.50 | median cbt mc 10.12 | Time Elapsed: 20.33 |
# Epoch: 10  |  cbt loss : 19.42 | reservoir loss : 0.0928 | bio loss : 0.82968 | total loss: 79.48 | median cbt mc 9.28 | Time Elapsed: 48.98 |
# Epoch: 20  |  cbt loss : 16.32 | reservoir loss : 0.0926 | bio loss : 0.58763 | total loss: 64.22 | median cbt mc 10.26 | Time Elapsed: 46.49 |
# Epoch: 30  |  cbt loss : 14.12 | reservoir loss : 0.0925 | bio loss : 0.58756 | total loss: 62.00 | median cbt mc 10.26 | Time Elapsed: 43.71 |
# Epoch: 40  |  cbt loss : 13.02 | reservoir loss : 0.0925 | bio loss : 0.58067 | total loss: 60.55 | median cbt mc 10.27 | Time Elapsed: 46.74 |
# Epoch: 50  |  cbt loss : 12.43 | reservoir loss : 0.0925 | bio loss : 0.57796 | total loss: 59.83 | median cbt mc 10.26 | Time Elapsed: 50.10 |
# Epoch: 60  |  cbt loss : 12.06 | reservoir loss : 0.0925 | bio loss : 0.57171 | total loss: 59.14 | median cbt mc 10.26 | Time Elapsed: 50.31 |
# Epoch: 70  |  cbt loss : 11.79 | reservoir loss : 0.0925 | bio loss : 0.57949 | total loss: 59.25 | median cbt mc 10.25 | Time Elapsed: 87.89 |
# Epoch: 80  |  cbt loss : 11.59 | reservoir loss : 0.0925 | bio loss : 0.59490 | total loss: 59.82 | median cbt mc 10.26 | Time Elapsed: 46.00 |
# Epoch: 90  |  cbt loss : 11.45 | reservoir loss : 0.0925 | bio loss : 0.59564 | total loss: 59.73 | median cbt mc 10.25 | Time Elapsed: 47.72 |
# Epoch: 100  |  cbt loss : 11.37 | reservoir loss : 0.0925 | bio loss : 0.59336 | total loss: 59.53 | median cbt mc 10.20 | Time Elapsed: 46.92 |
# Epoch: 110  |  cbt loss : 11.32 | reservoir loss : 0.0925 | bio loss : 0.59158 | total loss: 59.39 | median cbt mc 10.26 | Time Elapsed: 70.01 |
# Epoch: 120  |  cbt loss : 11.28 | reservoir loss : 0.0925 | bio loss : 0.60355 | total loss: 59.95 | median cbt mc 10.27 | Time Elapsed: 42.70 |
# Epoch: 130  |  cbt loss : 11.26 | reservoir loss : 0.0925 | bio loss : 0.81300 | total loss: 70.40 | median cbt mc 9.33 | Time Elapsed: 43.61 |
# Epoch: 140  |  cbt loss : 11.25 | reservoir loss : 0.0925 | bio loss : 0.57382 | total loss: 58.43 | median cbt mc 10.26 | Time Elapsed: 43.39 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.58395 | total loss: 58.93 | median cbt mc 10.26 | Time Elapsed: 46.62 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.58944 | total loss: 59.20 | median cbt mc 10.26 | Time Elapsed: 43.20 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.58394 | total loss: 58.93 | median cbt mc 10.27 | Time Elapsed: 43.18 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.58894 | total loss: 59.18 | median cbt mc 10.27 | Time Elapsed: 84.04 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.59505 | total loss: 59.48 | median cbt mc 10.26 | Time Elapsed: 157.46 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.24 | reservoir loss : 0.0925 | bio loss : 0.60894 | total loss: 60.18 | median cbt mc 10.25 | Time Elapsed: 161.34 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5800813371001915
# FINAL RESULTS  REP: 11.24095344543457, RESERVOIR LOSS: 0.08302849531173706, MEMORY FINGERPRINT: 9.471570464792883
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 26.46 | reservoir loss : 0.0932 | bio loss : 0.84389 | total loss: 87.30 | median cbt mc 9.26 | Time Elapsed: 65.92 |
# Epoch: 10  |  cbt loss : 20.24 | reservoir loss : 0.0923 | bio loss : 0.83698 | total loss: 80.55 | median cbt mc 9.26 | Time Elapsed: 159.53 |
# Epoch: 20  |  cbt loss : 15.85 | reservoir loss : 0.0921 | bio loss : 0.60831 | total loss: 64.69 | median cbt mc 10.26 | Time Elapsed: 160.39 |
# Epoch: 30  |  cbt loss : 13.20 | reservoir loss : 0.0920 | bio loss : 0.58216 | total loss: 60.71 | median cbt mc 10.25 | Time Elapsed: 149.11 |
# Epoch: 40  |  cbt loss : 12.12 | reservoir loss : 0.0920 | bio loss : 0.58033 | total loss: 59.53 | median cbt mc 10.27 | Time Elapsed: 42.29 |
# Epoch: 50  |  cbt loss : 11.64 | reservoir loss : 0.0920 | bio loss : 0.59239 | total loss: 59.65 | median cbt mc 10.26 | Time Elapsed: 43.44 |
# Epoch: 60  |  cbt loss : 11.43 | reservoir loss : 0.0920 | bio loss : 0.57779 | total loss: 58.71 | median cbt mc 10.26 | Time Elapsed: 43.92 |
# Epoch: 70  |  cbt loss : 11.38 | reservoir loss : 0.0919 | bio loss : 0.59478 | total loss: 59.51 | median cbt mc 10.25 | Time Elapsed: 42.69 |
# Epoch: 80  |  cbt loss : 11.32 | reservoir loss : 0.0919 | bio loss : 0.61990 | total loss: 60.70 | median cbt mc 10.26 | Time Elapsed: 43.36 |
# Epoch: 90  |  cbt loss : 11.22 | reservoir loss : 0.0919 | bio loss : 0.61335 | total loss: 60.27 | median cbt mc 10.26 | Time Elapsed: 42.19 |
# Epoch: 100  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.59379 | total loss: 59.26 | median cbt mc 10.26 | Time Elapsed: 42.88 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.58221 | total loss: 58.68 | median cbt mc 10.26 | Time Elapsed: 84.04 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.58621 | total loss: 58.88 | median cbt mc 10.27 | Time Elapsed: 44.32 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.60570 | total loss: 59.85 | median cbt mc 10.26 | Time Elapsed: 43.47 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.59531 | total loss: 59.33 | median cbt mc 10.31 | Time Elapsed: 62.80 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.60354 | total loss: 59.74 | median cbt mc 10.27 | Time Elapsed: 45.28 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.18 | reservoir loss : 0.0919 | bio loss : 0.58793 | total loss: 58.96 | median cbt mc 10.27 | Time Elapsed: 44.57 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.607322192493584
# FINAL RESULTS  REP: 11.176715850830078, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.439117817334237
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 63.90 | reservoir loss : 0.0912 | bio loss : 0.86518 | total loss: 125.39 | median cbt mc 9.25 | Time Elapsed: 17.30 |
# Epoch: 10  |  cbt loss : 42.46 | reservoir loss : 0.0905 | bio loss : 0.86362 | total loss: 103.74 | median cbt mc 9.25 | Time Elapsed: 44.57 |
# Epoch: 20  |  cbt loss : 28.97 | reservoir loss : 0.0903 | bio loss : 0.84068 | total loss: 89.05 | median cbt mc 9.27 | Time Elapsed: 44.36 |
# Epoch: 30  |  cbt loss : 20.69 | reservoir loss : 0.0902 | bio loss : 0.83073 | total loss: 80.27 | median cbt mc 9.30 | Time Elapsed: 41.62 |
# Epoch: 40  |  cbt loss : 15.27 | reservoir loss : 0.0902 | bio loss : 0.60338 | total loss: 63.47 | median cbt mc 10.27 | Time Elapsed: 43.71 |
# Epoch: 50  |  cbt loss : 13.16 | reservoir loss : 0.0902 | bio loss : 0.60280 | total loss: 61.33 | median cbt mc 10.26 | Time Elapsed: 44.98 |
# Epoch: 60  |  cbt loss : 12.38 | reservoir loss : 0.0902 | bio loss : 0.59193 | total loss: 60.01 | median cbt mc 10.26 | Time Elapsed: 46.07 |
# Epoch: 70  |  cbt loss : 11.88 | reservoir loss : 0.0902 | bio loss : 0.61963 | total loss: 60.89 | median cbt mc 10.26 | Time Elapsed: 135.68 |
# Epoch: 80  |  cbt loss : 11.64 | reservoir loss : 0.0901 | bio loss : 0.60960 | total loss: 60.15 | median cbt mc 10.26 | Time Elapsed: 80.53 |
# Epoch: 90  |  cbt loss : 11.48 | reservoir loss : 0.0901 | bio loss : 0.60456 | total loss: 59.74 | median cbt mc 10.27 | Time Elapsed: 42.65 |
# Epoch: 100  |  cbt loss : 11.39 | reservoir loss : 0.0901 | bio loss : 0.59518 | total loss: 59.18 | median cbt mc 10.26 | Time Elapsed: 43.29 |
# Epoch: 110  |  cbt loss : 11.29 | reservoir loss : 0.0901 | bio loss : 0.60778 | total loss: 59.71 | median cbt mc 10.26 | Time Elapsed: 42.93 |
# Epoch: 120  |  cbt loss : 11.20 | reservoir loss : 0.0901 | bio loss : 0.59846 | total loss: 59.15 | median cbt mc 10.27 | Time Elapsed: 44.12 |
# Epoch: 130  |  cbt loss : 11.14 | reservoir loss : 0.0901 | bio loss : 0.59045 | total loss: 58.69 | median cbt mc 10.26 | Time Elapsed: 42.24 |
# Epoch: 140  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.57566 | total loss: 57.93 | median cbt mc 10.26 | Time Elapsed: 41.50 |
# Epoch: 150  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.60267 | total loss: 59.27 | median cbt mc 10.27 | Time Elapsed: 41.62 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.60344 | total loss: 59.31 | median cbt mc 10.27 | Time Elapsed: 42.74 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.61019 | total loss: 59.65 | median cbt mc 10.27 | Time Elapsed: 85.87 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.58835 | total loss: 58.55 | median cbt mc 10.27 | Time Elapsed: 156.59 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.61647 | total loss: 59.96 | median cbt mc 10.26 | Time Elapsed: 146.51 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.60192 | total loss: 59.23 | median cbt mc 10.26 | Time Elapsed: 115.72 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.11 | reservoir loss : 0.0901 | bio loss : 0.60907 | total loss: 59.59 | median cbt mc 10.26 | Time Elapsed: 156.69 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.6098717166466425
# FINAL RESULTS  REP: 11.106014251708984, RESERVOIR LOSS: 0.0830283984541893, MEMORY FINGERPRINT: 10.433653621310453
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 75.32 | reservoir loss : 0.0919 | bio loss : 0.88566 | total loss: 137.98 | median cbt mc 9.26 | Time Elapsed: 42.97 |
# Epoch: 10  |  cbt loss : 47.92 | reservoir loss : 0.0911 | bio loss : 0.84700 | total loss: 108.49 | median cbt mc 9.27 | Time Elapsed: 158.18 |
# Epoch: 20  |  cbt loss : 28.83 | reservoir loss : 0.0909 | bio loss : 0.59752 | total loss: 76.89 | median cbt mc 10.26 | Time Elapsed: 158.15 |
# Epoch: 30  |  cbt loss : 20.85 | reservoir loss : 0.0908 | bio loss : 0.60604 | total loss: 69.31 | median cbt mc 10.26 | Time Elapsed: 137.74 |
# Epoch: 40  |  cbt loss : 17.53 | reservoir loss : 0.0908 | bio loss : 0.59768 | total loss: 65.58 | median cbt mc 10.27 | Time Elapsed: 41.48 |
# Epoch: 50  |  cbt loss : 15.34 | reservoir loss : 0.0908 | bio loss : 0.59394 | total loss: 63.20 | median cbt mc 10.27 | Time Elapsed: 42.84 |
# Epoch: 60  |  cbt loss : 14.30 | reservoir loss : 0.0908 | bio loss : 0.58622 | total loss: 61.77 | median cbt mc 10.27 | Time Elapsed: 42.20 |
# Epoch: 70  |  cbt loss : 13.50 | reservoir loss : 0.0908 | bio loss : 0.59297 | total loss: 61.30 | median cbt mc 10.27 | Time Elapsed: 40.95 |
# Epoch: 80  |  cbt loss : 12.89 | reservoir loss : 0.0908 | bio loss : 0.60276 | total loss: 61.18 | median cbt mc 10.26 | Time Elapsed: 42.67 |
# Epoch: 90  |  cbt loss : 12.41 | reservoir loss : 0.0908 | bio loss : 0.59293 | total loss: 60.22 | median cbt mc 10.28 | Time Elapsed: 43.23 |
# Epoch: 100  |  cbt loss : 12.07 | reservoir loss : 0.0908 | bio loss : 0.58665 | total loss: 59.56 | median cbt mc 10.26 | Time Elapsed: 43.62 |
# Epoch: 110  |  cbt loss : 11.80 | reservoir loss : 0.0908 | bio loss : 0.59899 | total loss: 59.91 | median cbt mc 10.25 | Time Elapsed: 105.14 |
# Epoch: 120  |  cbt loss : 11.64 | reservoir loss : 0.0908 | bio loss : 0.59308 | total loss: 59.45 | median cbt mc 10.27 | Time Elapsed: 40.11 |
# Epoch: 130  |  cbt loss : 11.54 | reservoir loss : 0.0908 | bio loss : 0.59048 | total loss: 59.22 | median cbt mc 10.25 | Time Elapsed: 41.21 |
# Epoch: 140  |  cbt loss : 11.47 | reservoir loss : 0.0908 | bio loss : 0.58974 | total loss: 59.12 | median cbt mc 10.25 | Time Elapsed: 43.19 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.41 | reservoir loss : 0.0908 | bio loss : 0.58168 | total loss: 58.65 | median cbt mc 10.26 | Time Elapsed: 43.46 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.41 | reservoir loss : 0.0908 | bio loss : 0.60548 | total loss: 59.84 | median cbt mc 10.25 | Time Elapsed: 42.87 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.41 | reservoir loss : 0.0908 | bio loss : 0.58752 | total loss: 58.94 | median cbt mc 10.24 | Time Elapsed: 44.02 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.41 | reservoir loss : 0.0908 | bio loss : 0.59927 | total loss: 59.53 | median cbt mc 10.26 | Time Elapsed: 40.60 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.843894380697633
# FINAL RESULTS  REP: 11.408598899841309, RESERVOIR LOSS: 0.0830284059047699, MEMORY FINGERPRINT: 10.355210676901192
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 94.94 | reservoir loss : 0.0901 | bio loss : 0.85674 | total loss: 155.81 | median cbt mc 9.26 | Time Elapsed: 15.59 |
# Epoch: 10  |  cbt loss : 68.99 | reservoir loss : 0.0895 | bio loss : 0.85535 | total loss: 129.64 | median cbt mc 9.26 | Time Elapsed: 43.83 |
# Epoch: 20  |  cbt loss : 48.49 | reservoir loss : 0.0893 | bio loss : 0.84607 | total loss: 108.65 | median cbt mc 9.30 | Time Elapsed: 42.79 |
# Epoch: 30  |  cbt loss : 35.18 | reservoir loss : 0.0892 | bio loss : 0.75124 | total loss: 90.59 | median cbt mc 9.41 | Time Elapsed: 41.76 |
# Epoch: 40  |  cbt loss : 26.36 | reservoir loss : 0.0892 | bio loss : 0.60832 | total loss: 74.61 | median cbt mc 10.25 | Time Elapsed: 42.40 |
# Epoch: 50  |  cbt loss : 19.32 | reservoir loss : 0.0892 | bio loss : 0.62468 | total loss: 68.38 | median cbt mc 9.79 | Time Elapsed: 40.87 |
# Epoch: 60  |  cbt loss : 13.88 | reservoir loss : 0.0892 | bio loss : 0.59174 | total loss: 61.30 | median cbt mc 10.27 | Time Elapsed: 40.57 |
# Epoch: 70  |  cbt loss : 12.80 | reservoir loss : 0.0892 | bio loss : 0.60647 | total loss: 60.95 | median cbt mc 10.26 | Time Elapsed: 40.06 |
# Epoch: 80  |  cbt loss : 12.27 | reservoir loss : 0.0892 | bio loss : 0.61109 | total loss: 60.66 | median cbt mc 10.27 | Time Elapsed: 41.90 |
# Epoch: 90  |  cbt loss : 11.94 | reservoir loss : 0.0892 | bio loss : 0.58887 | total loss: 59.22 | median cbt mc 10.26 | Time Elapsed: 42.39 |
# Epoch: 100  |  cbt loss : 11.69 | reservoir loss : 0.0892 | bio loss : 0.60694 | total loss: 59.87 | median cbt mc 10.24 | Time Elapsed: 42.54 |
# Epoch: 110  |  cbt loss : 11.51 | reservoir loss : 0.0892 | bio loss : 0.58867 | total loss: 58.78 | median cbt mc 10.25 | Time Elapsed: 42.21 |
# Epoch: 120  |  cbt loss : 11.39 | reservoir loss : 0.0892 | bio loss : 0.60035 | total loss: 59.24 | median cbt mc 10.26 | Time Elapsed: 41.92 |
# Epoch: 130  |  cbt loss : 11.31 | reservoir loss : 0.0892 | bio loss : 0.60942 | total loss: 59.61 | median cbt mc 10.24 | Time Elapsed: 41.90 |
# Epoch: 140  |  cbt loss : 11.26 | reservoir loss : 0.0892 | bio loss : 0.61560 | total loss: 59.88 | median cbt mc 10.25 | Time Elapsed: 42.63 |
# Epoch: 150  |  cbt loss : 11.23 | reservoir loss : 0.0892 | bio loss : 0.61310 | total loss: 59.72 | median cbt mc 10.26 | Time Elapsed: 45.00 |
# Epoch: 160  |  cbt loss : 11.21 | reservoir loss : 0.0892 | bio loss : 0.59882 | total loss: 58.98 | median cbt mc 10.26 | Time Elapsed: 42.94 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.58932 | total loss: 58.49 | median cbt mc 10.26 | Time Elapsed: 42.39 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.59074 | total loss: 58.56 | median cbt mc 10.26 | Time Elapsed: 43.19 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.59993 | total loss: 59.02 | median cbt mc 10.26 | Time Elapsed: 42.53 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.58759 | total loss: 58.40 | median cbt mc 10.25 | Time Elapsed: 42.89 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.61480 | total loss: 59.76 | median cbt mc 10.25 | Time Elapsed: 42.27 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.60405 | total loss: 59.22 | median cbt mc 10.25 | Time Elapsed: 42.59 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 11.19 | reservoir loss : 0.0892 | bio loss : 0.58905 | total loss: 58.47 | median cbt mc 10.25 | Time Elapsed: 42.61 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5973035634034013
# FINAL RESULTS  REP: 11.18825912475586, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.407376909575882

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def Frob_plot_multiview3(Frob_dist_DGN, Frob_dist_RC_integrated, Frob_dist_Third, up, low):
    mean_DGN = np.mean(Frob_dist_DGN)
    std_DGN = np.std(Frob_dist_DGN, ddof=1)
    
    mean_RC_integrated = np.mean(Frob_dist_RC_integrated)
    std_RC_integrated = np.std(Frob_dist_RC_integrated, ddof=1)
    
    mean_Third = np.mean(Frob_dist_Third)
    std_Third = np.std(Frob_dist_Third, ddof=1)

    data = {
        "Model": ["CBT_Loss_only"]*6 + ["RC_integrated"]*6 + ["RC_integrated_asd_with_bio"]*6,
        "Frobenius Distance": np.concatenate([Frob_dist_DGN, [mean_DGN], Frob_dist_RC_integrated, [mean_RC_integrated], Frob_dist_Third, [mean_Third]]),
        "Fold": ['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5', 'Mean']*3
    }

    df = pd.DataFrame(data)

    # Plotting
    plt.figure(figsize=(8, 5))
    ax = sns.barplot(data=df, x="Fold", y="Frobenius Distance", hue="Model")

    x_ticks = ax.get_xticks()
    hues = df["Model"].unique()
    n_hues = len(hues)
    bar_width = ax.patches[0].get_width()
    means = [mean_DGN, mean_RC_integrated, mean_Third]
    stds = [std_DGN, std_RC_integrated, std_Third]
    
    for i, hue in enumerate(hues):
        mean_pos = x_ticks[-1] + i * bar_width - bar_width * (n_hues - 1) / 2
        ax.errorbar(mean_pos, means[i], yerr=stds[i], fmt='none', ecolor='black', capsize=5, capthick=2)

    plt.legend(frameon=True)
    plt.ylim(up, low)  # Set the y-axis scale
    plt.tight_layout()
    plt.show()

# %%
# cbt loss
one_loss = [11.18, 11.22, 11.08, 11.20, 11.22]
two_loss = [11.240102767944336,
11.19381332397461,
11.112661361694336,
11.282367706298828,
11.20]
three_loss = [11.24, 11.18, 11.11, 11.41, 11.19]

print(np.mean(one_loss), np.mean(two_loss), np.mean(three_loss))
print(np.std(one_loss), np.std(two_loss), np.std(three_loss))

Frob_plot_multiview3(one_loss, two_loss, three_loss, 11, 11.45)
# Out:
# 11.179999999999998 11.205789031982423 11.225999999999999
# 0.052153619241621305 0.056376270331745984 0.10091580649234316

# %%
# bio loss for test nc
one = [0.5919172365095117, 0.6295159220589653, 0.592551133589266, 0.6023000116707593, 0.5925800476562322]
two = [0.5953083921918437,
0.6014780313191435,
0.5940165802680309,
0.5851465279148385,
0.6147388714396034]
three = [0.602180289808179, 0.5940104921923335, 0.5942473520032576, 0.5970199894152028, 0.5924795821343332] 

print(np.mean(one), np.mean(two), np.mean(three))
print(np.std(one), np.std(two), np.std(three))

Frob_plot_multiview3(one, two, three, 0.58, 0.63)
# Out:
# 0.6017728702969468 0.5981376806266919 0.5959875411106612
# 0.014398866152996076 0.009803222624746172 0.0034251669351068425

# %%
# memory capacity
one = [10.379720568978476, 10.432787816045513, 10.38085155501451, 10.407863754976127, 10.424775680663904]
two = [10.441380765879783,
10.418963089426375,
10.394259891987835,
10.433988876603197,
10.421402826371503]
three = [10.41781494024774, 10.426149181730434, 10.448260192883543, 10.432407947295289, 10.421950072660666]

print(np.mean(one), np.mean(two), np.mean(three))
print(np.std(one), np.std(two), np.std(three))

Frob_plot_multiview3(one, two, three, 10.37, 10.45)
# Out:
# 10.405199875135706 10.421999090053738 10.429316466963535
# 0.021878933413231695 0.016114839613567362 0.010630170082753557
