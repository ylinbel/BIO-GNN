# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys
import helper


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       3 import warnings
#       4 import numpy as np
# ----> 5 from model import DGN
#       6 from scipy.io import loadmat
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'model'

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
import scipy.io
import numpy as np

connectivity_matrices_asd = []

for i in range(1, 155):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/ASD_LH/LHASDSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_asd.append(connectivity_matrix)

connectivity_matrices_asd = np.stack(connectivity_matrices_asd)

connectivity_matrices_control = []

for i in range(1, 186):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/NC_LH/LHNCSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_control.append(connectivity_matrix)

connectivity_matrices_control = np.stack(connectivity_matrices_control)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# #### 3. train DGN for ASD

# %%
Dataset = "E" 
N_Subjects = 155
N_Nodes = 35
N_views = 6
N_max_epochs = 500
early_stop =  True
random_sample_size = 10
n_folds = 5
lr = 0.002
model_name = "asd_l_test"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 25
patience = 6
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_asd
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
# lambda2 = 
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                
                
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 25.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 23.88 | reservoir loss : 0.0933 | bio loss : 0.62213 | total loss: 43.17 | median cbt mc 9.84 | Time Elapsed: 65.31 |
# Epoch: 10  |  cbt loss : 14.79 | reservoir loss : 0.0920 | bio loss : 0.58664 | total loss: 29.46 | median cbt mc 10.26 | Time Elapsed: 58.04 |
# Epoch: 20  |  cbt loss : 12.54 | reservoir loss : 0.0916 | bio loss : 0.59525 | total loss: 27.42 | median cbt mc 10.26 | Time Elapsed: 50.46 |
# Epoch: 30  |  cbt loss : 11.69 | reservoir loss : 0.0914 | bio loss : 0.59772 | total loss: 26.64 | median cbt mc 10.25 | Time Elapsed: 50.98 |
# Epoch: 40  |  cbt loss : 11.37 | reservoir loss : 0.0914 | bio loss : 0.59980 | total loss: 26.37 | median cbt mc 10.27 | Time Elapsed: 50.11 |
# Epoch: 50  |  cbt loss : 11.19 | reservoir loss : 0.0913 | bio loss : 0.59468 | total loss: 26.06 | median cbt mc 10.25 | Time Elapsed: 55.88 |
# Epoch: 60  |  cbt loss : 11.12 | reservoir loss : 0.0913 | bio loss : 0.58279 | total loss: 25.68 | median cbt mc 10.26 | Time Elapsed: 102.28 |
# Epoch: 70  |  cbt loss : 11.13 | reservoir loss : 0.0913 | bio loss : 0.61125 | total loss: 26.42 | median cbt mc 10.27 | Time Elapsed: 114.91 |
# Epoch: 80  |  cbt loss : 11.17 | reservoir loss : 0.0913 | bio loss : 0.60621 | total loss: 26.33 | median cbt mc 10.25 | Time Elapsed: 110.40 |
# Epoch: 90  |  cbt loss : 11.22 | reservoir loss : 0.0913 | bio loss : 0.60454 | total loss: 26.33 | median cbt mc 10.25 | Time Elapsed: 101.24 |
# Epoch: 100  |  cbt loss : 11.25 | reservoir loss : 0.0913 | bio loss : 0.59819 | total loss: 26.20 | median cbt mc 10.29 | Time Elapsed: 106.09 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.25 | reservoir loss : 0.0913 | bio loss : 0.60258 | total loss: 26.31 | median cbt mc 10.26 | Time Elapsed: 104.66 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.58938 | total loss: 25.98 | median cbt mc 10.26 | Time Elapsed: 42.77 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59485 | total loss: 26.11 | median cbt mc 10.26 | Time Elapsed: 41.36 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.60235 | total loss: 26.30 | median cbt mc 10.26 | Time Elapsed: 41.70 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59925 | total loss: 26.22 | median cbt mc 10.25 | Time Elapsed: 42.82 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.58748 | total loss: 25.93 | median cbt mc 10.26 | Time Elapsed: 42.16 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59111 | total loss: 26.02 | median cbt mc 10.26 | Time Elapsed: 41.56 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59754 | total loss: 26.18 | median cbt mc 10.25 | Time Elapsed: 41.02 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59121 | total loss: 26.02 | median cbt mc 10.26 | Time Elapsed: 40.00 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59314 | total loss: 26.07 | median cbt mc 10.26 | Time Elapsed: 40.27 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59218 | total loss: 26.05 | median cbt mc 10.26 | Time Elapsed: 41.25 |
# CBT loss has converged.
# Epoch: 250  |  cbt loss : 11.24 | reservoir loss : 0.0932 | bio loss : 0.59481 | total loss: 26.11 | median cbt mc 10.26 | Time Elapsed: 43.18 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5962991727405166
# FINAL RESULTS  REP: 11.242877006530762, RESERVOIR LOSS: 0.0830284133553505, MEMORY FINGERPRINT: 10.40780481492399
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 56.88 | reservoir loss : 0.0912 | bio loss : 0.85962 | total loss: 78.37 | median cbt mc 9.24 | Time Elapsed: 36.30 |
# Epoch: 10  |  cbt loss : 25.85 | reservoir loss : 0.0912 | bio loss : 0.85141 | total loss: 47.14 | median cbt mc 9.28 | Time Elapsed: 41.50 |
# Epoch: 20  |  cbt loss : 13.79 | reservoir loss : 0.0912 | bio loss : 0.59964 | total loss: 28.78 | median cbt mc 10.23 | Time Elapsed: 42.56 |
# Epoch: 30  |  cbt loss : 11.38 | reservoir loss : 0.0912 | bio loss : 0.59486 | total loss: 26.25 | median cbt mc 10.23 | Time Elapsed: 41.48 |
# Epoch: 40  |  cbt loss : 11.15 | reservoir loss : 0.0912 | bio loss : 0.59753 | total loss: 26.08 | median cbt mc 10.26 | Time Elapsed: 40.14 |
# Epoch: 50  |  cbt loss : 11.24 | reservoir loss : 0.0912 | bio loss : 0.59417 | total loss: 26.09 | median cbt mc 10.26 | Time Elapsed: 40.08 |
# Epoch: 60  |  cbt loss : 11.15 | reservoir loss : 0.0912 | bio loss : 0.58863 | total loss: 25.86 | median cbt mc 10.26 | Time Elapsed: 41.15 |
# Epoch: 70  |  cbt loss : 11.16 | reservoir loss : 0.0912 | bio loss : 0.59624 | total loss: 26.07 | median cbt mc 10.26 | Time Elapsed: 40.85 |
# Epoch: 80  |  cbt loss : 11.19 | reservoir loss : 0.0912 | bio loss : 0.60063 | total loss: 26.20 | median cbt mc 10.26 | Time Elapsed: 42.01 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59558 | total loss: 26.12 | median cbt mc 10.25 | Time Elapsed: 41.69 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59531 | total loss: 26.12 | median cbt mc 10.27 | Time Elapsed: 41.67 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.58865 | total loss: 25.95 | median cbt mc 10.26 | Time Elapsed: 44.76 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59687 | total loss: 26.16 | median cbt mc 10.26 | Time Elapsed: 42.93 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.58521 | total loss: 25.86 | median cbt mc 10.27 | Time Elapsed: 40.16 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.58048 | total loss: 25.75 | median cbt mc 10.26 | Time Elapsed: 39.81 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59893 | total loss: 26.21 | median cbt mc 10.26 | Time Elapsed: 40.24 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59266 | total loss: 26.05 | median cbt mc 10.25 | Time Elapsed: 39.79 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.23 | reservoir loss : 0.0912 | bio loss : 0.59069 | total loss: 26.00 | median cbt mc 10.26 | Time Elapsed: 39.01 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.12 | reservoir loss : 0.0919 | bio loss : 0.59575 | total loss: 26.02 | median cbt mc 10.26 | Time Elapsed: 40.87 |
# Epoch: 140  |  cbt loss : 11.14 | reservoir loss : 0.0919 | bio loss : 0.58951 | total loss: 25.87 | median cbt mc 10.25 | Time Elapsed: 41.57 |
# Epoch: 150  |  cbt loss : 11.14 | reservoir loss : 0.0919 | bio loss : 0.59804 | total loss: 26.09 | median cbt mc 10.26 | Time Elapsed: 41.77 |
# Epoch: 160  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.61015 | total loss: 26.40 | median cbt mc 10.26 | Time Elapsed: 41.72 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59325 | total loss: 25.98 | median cbt mc 10.26 | Time Elapsed: 41.25 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59363 | total loss: 25.99 | median cbt mc 10.25 | Time Elapsed: 40.75 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.60296 | total loss: 26.23 | median cbt mc 10.25 | Time Elapsed: 39.84 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.60077 | total loss: 26.17 | median cbt mc 10.27 | Time Elapsed: 40.21 |
# CBT loss has converged.
# Epoch: 210  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59004 | total loss: 25.90 | median cbt mc 10.26 | Time Elapsed: 40.92 |
# CBT loss has converged.
# Epoch: 220  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59306 | total loss: 25.98 | median cbt mc 10.26 | Time Elapsed: 41.98 |
# CBT loss has converged.
# Epoch: 230  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59486 | total loss: 26.02 | median cbt mc 10.25 | Time Elapsed: 40.41 |
# CBT loss has converged.
# Epoch: 240  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.60034 | total loss: 26.16 | median cbt mc 10.26 | Time Elapsed: 39.20 |
# CBT loss has converged.
# Epoch: 250  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.59808 | total loss: 26.10 | median cbt mc 10.26 | Time Elapsed: 38.62 |
# CBT loss has converged.
# Epoch: 260  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.58714 | total loss: 25.83 | median cbt mc 10.26 | Time Elapsed: 38.93 |
# CBT loss has converged.
# Epoch: 270  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.60087 | total loss: 26.17 | median cbt mc 10.26 | Time Elapsed: 39.32 |
# CBT loss has converged.
# Epoch: 70  |  cbt loss : 11.10 | reservoir loss : 0.0901 | bio loss : 0.60282 | total loss: 26.17 | median cbt mc 10.25 | Time Elapsed: 133.07 |
# Epoch: 80  |  cbt loss : 11.12 | reservoir loss : 0.0901 | bio loss : 0.59382 | total loss: 25.96 | median cbt mc 10.26 | Time Elapsed: 65.10 |
# Epoch: 90  |  cbt loss : 11.13 | reservoir loss : 0.0901 | bio loss : 0.60162 | total loss: 26.17 | median cbt mc 10.26 | Time Elapsed: 40.30 |
# Epoch: 100  |  cbt loss : 11.14 | reservoir loss : 0.0901 | bio loss : 0.60497 | total loss: 26.26 | median cbt mc 10.25 | Time Elapsed: 114.08 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.59896 | total loss: 26.13 | median cbt mc 10.26 | Time Elapsed: 52.86 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.59669 | total loss: 26.07 | median cbt mc 10.26 | Time Elapsed: 38.39 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.60231 | total loss: 26.21 | median cbt mc 10.21 | Time Elapsed: 51.46 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.58711 | total loss: 25.83 | median cbt mc 10.26 | Time Elapsed: 43.88 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.60616 | total loss: 26.31 | median cbt mc 10.26 | Time Elapsed: 45.12 |
# CBT loss has converged.
# Epoch: 160  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.60279 | total loss: 26.23 | median cbt mc 10.24 | Time Elapsed: 40.52 |
# CBT loss has converged.
# Epoch: 170  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.59538 | total loss: 26.04 | median cbt mc 10.26 | Time Elapsed: 40.05 |
# CBT loss has converged.
# Epoch: 180  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.58922 | total loss: 25.89 | median cbt mc 10.26 | Time Elapsed: 40.23 |
# CBT loss has converged.
# Epoch: 190  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.59193 | total loss: 25.95 | median cbt mc 10.26 | Time Elapsed: 40.76 |
# CBT loss has converged.
# Epoch: 200  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.58992 | total loss: 25.90 | median cbt mc 10.19 | Time Elapsed: 40.48 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5885672855349752
# FINAL RESULTS  REP: 11.155876159667969, RESERVOIR LOSS: 0.08302842825651169, MEMORY FINGERPRINT: 10.405886637600991
