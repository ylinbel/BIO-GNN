# %%
import scipy
import os
import warnings
import numpy as np
from model import DGN
from scipy.io import loadmat
import matplotlib.pyplot as plt
import torch.nn
import contextlib
import sys
import helper


plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Arial', 'Liberation Serif']

# %% [markdown]
# #### 1. inspect

# %% [markdown]
# #### 2. data preprocessing

# %%
def normalize_matrix(connectivity_matrix):
    np.fill_diagonal(connectivity_matrix, 0)
    connectivity_matrix[np.logical_or(np.isinf(connectivity_matrix), np.isnan(connectivity_matrix))] = 0
    connectivity_matrix = connectivity_matrix.astype(float)
    
    return connectivity_matrix

# %%
import scipy.io
import numpy as np

connectivity_matrices_asd = []

for i in range(1, 155):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/ASD_LH/LHASDSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_asd.append(connectivity_matrix)

connectivity_matrices_asd = np.stack(connectivity_matrices_asd)

connectivity_matrices_control = []

for i in range(1, 186):
    mat = scipy.io.loadmat(f'data_nc_asd_L/data_nc_asd_L/NC_LH/LHNCSub{i}.mat')
    connectivity_matrix = mat['views'][:, :, :]
    connectivity_matrix = [normalize_matrix(mat) for mat in connectivity_matrix]
    connectivity_matrices_control.append(connectivity_matrix)

connectivity_matrices_control = np.stack(connectivity_matrices_control)

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# #### 3. train DGN for ASD

# %%
Dataset = "E" 
N_Subjects = 155
N_Nodes = 35
N_views = 6
N_max_epochs = 500
early_stop =  True
random_sample_size = 10
n_folds = 5
lr = 0.002
model_name = "ASD_LH_rc_loss_only"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_asd
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# lambda r 200.0 lambda b 0.0
# ********* FOLD 0 *********
# Epoch: 0  |  cbt loss : 24.42 | reservoir loss : 0.0933 | bio loss : 0.00000 | total loss: 28.15 | median cbt mc 10.24 | Time Elapsed: 7.79 |
# Epoch: 10  |  cbt loss : 14.93 | reservoir loss : 0.0920 | bio loss : 0.00000 | total loss: 14.93 | median cbt mc 10.25 | Time Elapsed: 34.51 |
# Epoch: 20  |  cbt loss : 12.55 | reservoir loss : 0.0916 | bio loss : 0.00000 | total loss: 12.55 | median cbt mc 10.26 | Time Elapsed: 35.40 |
# Epoch: 30  |  cbt loss : 11.65 | reservoir loss : 0.0914 | bio loss : 0.00000 | total loss: 11.65 | median cbt mc 10.26 | Time Elapsed: 73.03 |
# Epoch: 40  |  cbt loss : 11.31 | reservoir loss : 0.0914 | bio loss : 0.00000 | total loss: 11.31 | median cbt mc 10.25 | Time Elapsed: 41.16 |
# Epoch: 50  |  cbt loss : 11.11 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.11 | median cbt mc 10.26 | Time Elapsed: 62.11 |
# Epoch: 60  |  cbt loss : 11.05 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.26 | Time Elapsed: 55.70 |
# Epoch: 70  |  cbt loss : 11.05 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.25 | Time Elapsed: 38.48 |
# Epoch: 80  |  cbt loss : 11.06 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.06 | median cbt mc 10.26 | Time Elapsed: 35.27 |
# Epoch: 90  |  cbt loss : 11.08 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.08 | median cbt mc 10.26 | Time Elapsed: 81.95 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.25 | Time Elapsed: 30.59 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.26 | Time Elapsed: 24.56 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.26 | Time Elapsed: 24.13 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.26 | Time Elapsed: 24.31 |
# CBT loss has converged.
# Epoch: 140  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.26 | Time Elapsed: 24.45 |
# CBT loss has converged.
# Epoch: 150  |  cbt loss : 11.09 | reservoir loss : 0.0913 | bio loss : 0.00000 | total loss: 11.09 | median cbt mc 10.26 | Time Elapsed: 24.84 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.571865140389225
# FINAL RESULTS  REP: 11.087087631225586, RESERVOIR LOSS: 0.08302845805883408, MEMORY FINGERPRINT: 10.406436742506582
# ********* FOLD 1 *********
# Epoch: 0  |  cbt loss : 24.63 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 24.63 | median cbt mc 9.27 | Time Elapsed: 4.45 |
# Epoch: 10  |  cbt loss : 14.74 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 14.74 | median cbt mc 9.27 | Time Elapsed: 30.25 |
# Epoch: 20  |  cbt loss : 11.71 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.71 | median cbt mc 10.26 | Time Elapsed: 29.07 |
# Epoch: 30  |  cbt loss : 11.22 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.22 | median cbt mc 10.26 | Time Elapsed: 29.29 |
# Epoch: 40  |  cbt loss : 11.12 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.12 | median cbt mc 10.26 | Time Elapsed: 29.79 |
# Epoch: 50  |  cbt loss : 11.17 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.17 | median cbt mc 10.27 | Time Elapsed: 32.55 |
# CBT loss has converged.
# Epoch: 60  |  cbt loss : 11.18 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 27.56 |
# CBT loss has converged.
# Epoch: 70  |  cbt loss : 11.18 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 24.81 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 11.18 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 24.28 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 11.18 | reservoir loss : 0.0932 | bio loss : 0.00000 | total loss: 11.18 | median cbt mc 10.26 | Time Elapsed: 24.32 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5852472395246464
# FINAL RESULTS  REP: 11.179631233215332, RESERVOIR LOSS: 0.08302842825651169, MEMORY FINGERPRINT: 10.430865515925202
# ********* FOLD 2 *********
# Epoch: 0  |  cbt loss : 57.98 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 57.98 | median cbt mc 9.27 | Time Elapsed: 4.42 |
# Epoch: 10  |  cbt loss : 26.23 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 26.23 | median cbt mc 9.27 | Time Elapsed: 28.83 |
# Epoch: 20  |  cbt loss : 13.89 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 13.89 | median cbt mc 10.24 | Time Elapsed: 28.89 |
# Epoch: 30  |  cbt loss : 11.30 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.30 | median cbt mc 10.25 | Time Elapsed: 29.14 |
# Epoch: 40  |  cbt loss : 11.06 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.06 | median cbt mc 9.28 | Time Elapsed: 28.46 |
# Epoch: 50  |  cbt loss : 11.14 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.14 | median cbt mc 10.27 | Time Elapsed: 28.78 |
# Epoch: 60  |  cbt loss : 11.03 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.03 | median cbt mc 10.26 | Time Elapsed: 29.15 |
# Epoch: 70  |  cbt loss : 11.03 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.03 | median cbt mc 9.45 | Time Elapsed: 28.46 |
# CBT loss has converged.
# Epoch: 80  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.25 | Time Elapsed: 28.72 |
# CBT loss has converged.
# Epoch: 90  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.26 | Time Elapsed: 24.28 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.24 | Time Elapsed: 23.86 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.26 | Time Elapsed: 30.01 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.24 | Time Elapsed: 30.25 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.05 | reservoir loss : 0.0912 | bio loss : 0.00000 | total loss: 11.05 | median cbt mc 10.25 | Time Elapsed: 23.94 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.6132868815862068
# FINAL RESULTS  REP: 11.049898147583008, RESERVOIR LOSS: 0.08302844315767288, MEMORY FINGERPRINT: 10.434978047245094
# ********* FOLD 3 *********
# Epoch: 0  |  cbt loss : 67.94 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 67.94 | median cbt mc 9.28 | Time Elapsed: 4.39 |
# Epoch: 10  |  cbt loss : 24.59 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 24.59 | median cbt mc 9.27 | Time Elapsed: 27.75 |
# Epoch: 20  |  cbt loss : 17.00 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 17.00 | median cbt mc 10.26 | Time Elapsed: 28.69 |
# Epoch: 30  |  cbt loss : 14.22 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 14.22 | median cbt mc 10.26 | Time Elapsed: 28.38 |
# Epoch: 40  |  cbt loss : 12.76 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 12.76 | median cbt mc 10.27 | Time Elapsed: 28.43 |
# Epoch: 50  |  cbt loss : 11.86 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.86 | median cbt mc 10.27 | Time Elapsed: 28.99 |
# Epoch: 60  |  cbt loss : 11.51 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.51 | median cbt mc 10.26 | Time Elapsed: 28.56 |
# Epoch: 70  |  cbt loss : 11.20 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.20 | median cbt mc 10.25 | Time Elapsed: 28.46 |
# Epoch: 80  |  cbt loss : 11.11 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.11 | median cbt mc 10.26 | Time Elapsed: 29.17 |
# Epoch: 90  |  cbt loss : 11.17 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.17 | median cbt mc 10.26 | Time Elapsed: 43.31 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.15 | median cbt mc 10.25 | Time Elapsed: 112.91 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.15 | median cbt mc 10.25 | Time Elapsed: 99.57 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.15 | median cbt mc 10.26 | Time Elapsed: 97.22 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.15 | reservoir loss : 0.0919 | bio loss : 0.00000 | total loss: 11.15 | median cbt mc 10.26 | Time Elapsed: 104.61 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.6187196539146437
# FINAL RESULTS  REP: 11.154363632202148, RESERVOIR LOSS: 0.08302843570709229, MEMORY FINGERPRINT: 10.427911455305555
# ********* FOLD 4 *********
# Epoch: 0  |  cbt loss : 87.56 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 87.56 | median cbt mc 9.27 | Time Elapsed: 18.78 |
# Epoch: 10  |  cbt loss : 42.70 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 42.70 | median cbt mc 9.27 | Time Elapsed: 118.85 |
# Epoch: 20  |  cbt loss : 23.08 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 23.08 | median cbt mc 10.23 | Time Elapsed: 120.48 |
# Epoch: 30  |  cbt loss : 13.01 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 13.01 | median cbt mc 10.27 | Time Elapsed: 121.28 |
# Epoch: 40  |  cbt loss : 11.79 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.79 | median cbt mc 10.27 | Time Elapsed: 118.54 |
# Epoch: 50  |  cbt loss : 11.30 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.30 | median cbt mc 10.26 | Time Elapsed: 120.14 |
# Epoch: 60  |  cbt loss : 11.21 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.21 | median cbt mc 10.22 | Time Elapsed: 120.22 |
# Epoch: 70  |  cbt loss : 11.13 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.13 | median cbt mc 10.26 | Time Elapsed: 120.69 |
# Epoch: 80  |  cbt loss : 11.15 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.15 | median cbt mc 10.26 | Time Elapsed: 119.97 |
# Epoch: 90  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.24 | Time Elapsed: 120.97 |
# CBT loss has converged.
# Epoch: 100  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.21 | Time Elapsed: 104.41 |
# CBT loss has converged.
# Epoch: 110  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.25 | Time Elapsed: 100.20 |
# CBT loss has converged.
# Epoch: 120  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.25 | Time Elapsed: 99.94 |
# CBT loss has converged.
# Epoch: 130  |  cbt loss : 11.16 | reservoir loss : 0.0901 | bio loss : 0.00000 | total loss: 11.16 | median cbt mc 10.18 | Time Elapsed: 100.55 |
# Early Stopping triggered based on lack of improvement in reservoir and biological losses.
# bio losses: 0.5905192542825591
# FINAL RESULTS  REP: 11.161864280700684, RESERVOIR LOSS: 0.0830284133553505, MEMORY FINGERPRINT: 10.394738010155201

# %%
Dataset = "E" 
N_Subjects = 186
N_Nodes = 35
N_views = 6
N_max_epochs = 500
early_stop =  True
random_sample_size = 10
n_folds = 5
lr = 0.001
model_name = "CONTROL_LH_rc_loss_only"

#dimension of embeddings output by the first GDL layer (for each ROI)
CONV1 = CONV2 = CONV3 = 8

lambda_r = 200
lambda_b = 0
patience = 3
convergence_threshold = 0.01

#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#
#                 Below is not to be modified manually                       #
#----------------------------------------------------------------------------#
#----------------------------------------------------------------------------#

import helper

if Dataset.lower() not in ["e", "E", "s", "S"]:
    raise ValueError("Dataset options are E or S.")
    
if (Dataset.lower() == "e"):
    X = connectivity_matrices_control
    N_Subjects = X.shape[0]
    N_Nodes = X.shape[1]
    N_views = X.shape[3]
else:
    X = helper.create_better_simulated(N_Subjects, N_Nodes) if N_views == 4 else helper.simulate_dataset(N_Subjects, N_Nodes, N_views)


CONFIG = {
        "X": X,
        "N_ROIs":  X.shape[1],
        "N_views":  X.shape[3],
        "N_max_epochs": N_max_epochs,
        "n_folds": n_folds,
        "random_sample_size": random_sample_size,
        "early_stop": early_stop,
        "model_name": model_name
    }

MODEL_PARAMS = {
        "N_ROIs": N_Nodes,
        "learning_rate" : lr,
        "n_attr": X.shape[3],
        "Linear1" : {"in": N_views, "out": CONV1},
        "conv1": {"in" : 1, "out": CONV1},
        
        "Linear2" : {"in": N_views, "out": CONV1*CONV2},
        "conv2": {"in" : CONV1, "out": CONV2},
        
        "Linear3" : {"in": N_views, "out": CONV2*CONV3},
        "conv3": {"in" : CONV2, "out": CONV3},
        "lambda_r" : lambda_r,
        "lambda_b" : lambda_b,
        "patience" : patience,
        "convergence_threshold" : convergence_threshold,
    }

# %%
np.random.seed(35813)
torch.manual_seed(35813)
models = DGN.train_model(
                CONFIG["X"],
                model_params=MODEL_PARAMS,
                n_max_epochs=CONFIG["N_max_epochs"],
                n_folds=CONFIG["n_folds"],
                random_sample_size=CONFIG["random_sample_size"],
                early_stop=CONFIG["early_stop"],
                model_name=CONFIG["model_name"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 np.random.seed(35813)
#       2 torch.manual_seed(35813)
#       3 models = DGN.train_model(
#       4                 CONFIG["X"],
#       5                 model_params=MODEL_PARAMS,
#    (...)
#       9                 early_stop=CONFIG["early_stop"],
#      10                 model_name=CONFIG["model_name"])
#
# NameError: name 'np' is not defined

# %%
import numpy as np

memory_capacity_ad = [
10.417149133870716,
10.437327277995314,
10.379170022320473,
10.411267372475839,
10.415995499002646,
]

bio = [
0.60701551833648,
0.5979423515748338,
0.6225680123512815,
0.6024750567419715,
0.5905899934166011,
]

fb = [
11.058025360107422,
11.331298828125,
10.9967784881591,
11.21181297302246,
11.010485649108887,
]

print("asd",  "memory capacity", np.mean(memory_capacity_ad), np.std(memory_capacity_ad), "bio", np.mean(bio), np.std(bio), "fb", np.mean(fb), np.std(fb))
# Out:
# asd memory capacity 10.412181861132998 0.018772998762688568 bio 0.6041181864842337 0.010701807569187899 fb 11.121680259704574 0.1296768988217414

# %%
memory_capacity_nc = [
10.470142460316918,
10.43984082427828,
9.45597704732938,
10.418562930600595,
10.418382349745507,
]

bio = [
0.5968123685827721,
0.5890540409379833,
0.588528350741875,
0.634754470414607,
0.561135150257032,
]

fb = [
11.175732612609863,
11.32252311706543,
11.023404121398926,
10.996713638305664,
11.183392524719238,
]

print("nc",  "memory capacity", np.mean(memory_capacity_nc), np.std(memory_capacity_nc), "bio", np.mean(bio), np.std(bio), "fb", np.mean(fb), np.std(fb))
# Out:
# nc memory capacity 10.240581122454136 0.392758753377228 bio 0.5940568761868539 0.023678344142242014 fb 11.140353202819824 0.11882708080392589
